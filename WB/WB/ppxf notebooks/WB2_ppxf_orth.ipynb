# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,
)

# %%
raw = np.load("../calibrated data/WB2_data_orth.npy")       # rename your 2D array
waveem = np.load("../calibrated data/WB2_waveem_orth.npy")

window_size = 5
step        = 1
scale       = 0.4   # arcsec per pixel

pix_min, pix_max = 150, 250   
results = []
raw_roi = raw[:, pix_min:pix_max]

for start in range(0, raw_roi.shape[1] - window_size + 1, step):
    end = start + window_size
    spectrum = raw_roi[:, start:end].sum(axis=1)

    # Build DataFrame for this spectrum
    df_spec = pd.DataFrame({
        "waveem": waveem,
        "flux":   spectrum
    })

    # Process, rebin, and run pPXF
    df_cut = process_spectrum(df_spec)
    noise = make_noise(df_cut)
    df_rb, lam, flux_rb, ln_w = rebin_to_log(df_cut)
    velscale, fwhm = calculate_velscale_fwhm(ln_w, lam)
    pp, gas_templates = run_ppxf(lam, fwhm, velscale, df_rb, noise)

    # Compute global center index
    center = start + window_size//2 + pix_min
    print(f'PIXEL: {center}')

    # Store center, rebinned DataFrame, and fit result
    results.append((center, df_rb, pp))
# Out:
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000      1000
#  comp.  1:       -27       194
#  comp.  2:        85       237
# chi2/DOF: 0.9438; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       9.6     -27   194
# Comp:  2           [NII]6583_d     0.5371       13.      85   237
# -----------------------------------------------------------------
# pPXF fit done in 1.96 s
# PIXEL: 152
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -121         1
#  comp.  1:        -6       199
#  comp.  2:        18       210
# chi2/DOF: 0.9857; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.017       10.      -6   199
# Comp:  2           [NII]6583_d      2.588       13.      18   210
# -----------------------------------------------------------------
# pPXF fit done in 1.83 s
# PIXEL: 153
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1170         1
#  comp.  1:        -0       200
#  comp.  2:       294        54
# chi2/DOF: 0.9653; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       13.      -0   200
# Comp:  2           [NII]6583_d      2.670       13.     294    54
# -----------------------------------------------------------------
# pPXF fit done in 2.00 s
# PIXEL: 154
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000         1
#  comp.  1:       -42       138
#  comp.  2:       352        87
# chi2/DOF: 0.9586; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       11.     -42   138
# Comp:  2           [NII]6583_d      3.612       13.     352    87
# -----------------------------------------------------------------
# pPXF fit done in 2.34 s
# PIXEL: 155
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1970         1
#  comp.  1:        -0       200
#  comp.  2:       248       181
# chi2/DOF: 0.9592; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       12.      -0   200
# Comp:  2           [NII]6583_d      4.495       14.     248   181
# -----------------------------------------------------------------
# pPXF fit done in 2.12 s
# PIXEL: 156
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1945         1
#  comp.  1:         1       195
#  comp.  2:       223       260
# chi2/DOF: 0.9623; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 195; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.3555       11.       1   195
# Comp:  2           [NII]6583_d      6.263       16.     223   260
# -----------------------------------------------------------------
# pPXF fit done in 3.69 s
# PIXEL: 157
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1858        25
#  comp.  1:         0       197
#  comp.  2:       132       257
# chi2/DOF: 0.9332; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 177; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       9.8       0   197
# Comp:  2           [NII]6583_d      3.820       14.     132   257
# -----------------------------------------------------------------
# pPXF fit done in 2.94 s
# PIXEL: 158
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1343         1
#  comp.  1:         0       200
#  comp.  2:        50       171
# chi2/DOF: 0.7940; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       5.6       0   200
# Comp:  2           [NII]6583_d      1.471       6.7      50   171
# -----------------------------------------------------------------
# pPXF fit done in 2.38 s
# PIXEL: 159
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       914       234
#  comp.  1:        -0       189
#  comp.  2:        -8       108
# chi2/DOF: 0.7434; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       4.5      -0   189
# Comp:  2           [NII]6583_d      1.118       4.9      -8   108
# -----------------------------------------------------------------
# pPXF fit done in 2.15 s
# PIXEL: 160
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       546       212
#  comp.  1:         4       189
#  comp.  2:        -8       118
# chi2/DOF: 0.7241; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       4.2       4   189
# Comp:  2           [NII]6583_d    0.02344       4.6      -8   118
# -----------------------------------------------------------------
# pPXF fit done in 1.74 s
# PIXEL: 161
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       511       125
#  comp.  1:      1032       301
#  comp.  2:        17        26
# chi2/DOF: 0.7042; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       5.7    1032   301
# Comp:  2           [NII]6583_d     0.9137       4.4      17    26
# -----------------------------------------------------------------
# pPXF fit done in 1.83 s
# PIXEL: 162
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       488       246
#  comp.  1:       211        18
#  comp.  2:        83        78
# chi2/DOF: 0.6938; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.6635       2.0     211    18
# Comp:  2           [NII]6583_d     0.4870       2.8      83    78
# -----------------------------------------------------------------
# pPXF fit done in 2.12 s
# PIXEL: 163
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       368        10
#  comp.  1:       147        82
#  comp.  2:        94         7
# chi2/DOF: 0.6819; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.674       2.1     147    82
# Comp:  2           [NII]6583_d      0.000       2.4      94     7
# -----------------------------------------------------------------
# pPXF fit done in 1.17 s
# PIXEL: 164
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       941       692
#  comp.  1:        99       112
#  comp.  2:        99       196
# chi2/DOF: 0.6734; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.403       2.0      99   112
# Comp:  2           [NII]6583_d     0.2117       3.0      99   196
# -----------------------------------------------------------------
# pPXF fit done in 1.04 s
# PIXEL: 165
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1266       476
#  comp.  1:        80       100
#  comp.  2:        39       270
# chi2/DOF: 0.6217; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.927       1.9      80   100
# Comp:  2           [NII]6583_d      0.000       3.3      39   270
# -----------------------------------------------------------------
# pPXF fit done in 3.10 s
# PIXEL: 166
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1115       823
#  comp.  1:        44        64
#  comp.  2:         0       200
# chi2/DOF: 0.6104; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 244; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.514       1.9      44    64
# Comp:  2           [NII]6583_d      0.000       3.2       0   200
# -----------------------------------------------------------------
# pPXF fit done in 3.87 s
# PIXEL: 167
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -983      1000
#  comp.  1:        32        74
#  comp.  2:       325        81
# chi2/DOF: 0.6199; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 177; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.216       1.8      32    74
# Comp:  2           [NII]6583_d     0.8451       2.4     325    81
# -----------------------------------------------------------------
# pPXF fit done in 3.22 s
# PIXEL: 168
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       269       500
#  comp.  1:        29        81
#  comp.  2:       137       134
# chi2/DOF: 0.5938; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.449       1.7      29    81
# Comp:  2           [NII]6583_d      1.201       2.5     137   134
# -----------------------------------------------------------------
# pPXF fit done in 2.55 s
# PIXEL: 169
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       223         1
#  comp.  1:        25       114
#  comp.  2:        72        23
# chi2/DOF: 0.6028; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.101       1.8      25   114
# Comp:  2           [NII]6583_d     0.8920       1.9      72    23
# -----------------------------------------------------------------
# pPXF fit done in 2.68 s
# PIXEL: 170
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -714       504
#  comp.  1:        -6        42
#  comp.  2:        42       121
# chi2/DOF: 0.6875; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.506       1.7      -6    42
# Comp:  2           [NII]6583_d      1.643       2.5      42   121
# -----------------------------------------------------------------
# pPXF fit done in 1.74 s
# PIXEL: 171
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1054       169
#  comp.  1:       -17         1
#  comp.  2:       -46         1
# chi2/DOF: 0.7285; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 190; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.236       1.6     -17     1
# Comp:  2           [NII]6583_d      1.549       2.0     -46     1
# -----------------------------------------------------------------
# pPXF fit done in 1.98 s
# PIXEL: 172
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1041        87
#  comp.  1:       -23         1
#  comp.  2:       -19         1
# chi2/DOF: 0.7392; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 226; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.083       1.6     -23     1
# Comp:  2           [NII]6583_d      1.915       2.0     -19     1
# -----------------------------------------------------------------
# pPXF fit done in 2.51 s
# PIXEL: 173
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1059       183
#  comp.  1:       -10         1
#  comp.  2:       -12         1
# chi2/DOF: 0.7595; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 207; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.414       1.6     -10     1
# Comp:  2           [NII]6583_d      1.565       2.0     -12     1
# -----------------------------------------------------------------
# pPXF fit done in 2.71 s
# PIXEL: 174
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1072        66
#  comp.  1:         8        60
#  comp.  2:        -5         1
# chi2/DOF: 0.7425; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.681       1.6       8    60
# Comp:  2           [NII]6583_d      1.444       1.9      -5     1
# -----------------------------------------------------------------
# pPXF fit done in 1.35 s
# PIXEL: 175
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1684      1000
#  comp.  1:         4        66
#  comp.  2:        49       101
# chi2/DOF: 0.6430; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 57; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.152       1.5       4    66
# Comp:  2           [NII]6583_d      1.572       2.0      49   101
# -----------------------------------------------------------------
# pPXF fit done in 0.93 s
# PIXEL: 176
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1849       741
#  comp.  1:        18        65
#  comp.  2:       158       138
# chi2/DOF: 0.6540; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 262; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.618       2.2      18    65
# Comp:  2           [NII]6583_d      1.350       3.2     158   138
# -----------------------------------------------------------------
# pPXF fit done in 4.89 s
# PIXEL: 177
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1012      1000
#  comp.  1:        31        66
#  comp.  2:       186       154
# chi2/DOF: 0.6516; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.392       2.2      31    66
# Comp:  2           [NII]6583_d      1.471       3.3     186   154
# -----------------------------------------------------------------
# pPXF fit done in 3.03 s
# PIXEL: 178
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1187       304
#  comp.  1:        20         1
#  comp.  2:       262       142
# chi2/DOF: 0.6475; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 18; Func calls: 315; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.371       2.0      20     1
# Comp:  2           [NII]6583_d      1.685       3.1     262   142
# -----------------------------------------------------------------
# pPXF fit done in 4.55 s
# PIXEL: 179
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -77       897
#  comp.  1:         7        53
#  comp.  2:       213       171
# chi2/DOF: 0.6760; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 73; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.182       2.2       7    53
# Comp:  2           [NII]6583_d      1.781       3.5     213   171
# -----------------------------------------------------------------
# pPXF fit done in 1.28 s
# PIXEL: 180
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       353        62
#  comp.  1:       251         1
#  comp.  2:      -833       178
# chi2/DOF: 0.7020; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       2.9     251     1
# Comp:  2           [NII]6583_d      2.656       5.0    -833   178
# -----------------------------------------------------------------
# pPXF fit done in 1.73 s
# PIXEL: 181
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       452       442
#  comp.  1:        91       201
#  comp.  2:       109       155
# chi2/DOF: 0.7315; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 22; Func calls: 380; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.507       2.2      91   201
# Comp:  2           [NII]6583_d      1.610       2.5     109   155
# -----------------------------------------------------------------
# pPXF fit done in 5.02 s
# PIXEL: 182
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       488       418
#  comp.  1:       105       143
#  comp.  2:        96       109
# chi2/DOF: 0.7379; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.365       1.9     105   143
# Comp:  2           [NII]6583_d      1.631       2.2      96   109
# -----------------------------------------------------------------
# pPXF fit done in 2.19 s
# PIXEL: 183
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000      1000
#  comp.  1:       -15        76
#  comp.  2:        29         1
# chi2/DOF: 0.7086; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 177; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.8752       1.6     -15    76
# Comp:  2           [NII]6583_d      1.566       1.9      29     1
# -----------------------------------------------------------------
# pPXF fit done in 2.40 s
# PIXEL: 184
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1036      1000
#  comp.  1:       -12       120
#  comp.  2:        51         1
# chi2/DOF: 0.5081; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.6251       1.4     -12   120
# Comp:  2           [NII]6583_d      1.494       1.4      51     1
# -----------------------------------------------------------------
# pPXF fit done in 3.09 s
# PIXEL: 185
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -892       375
#  comp.  1:        34        77
#  comp.  2:        44         1
# chi2/DOF: 0.3279; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 261; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.6790       1.1      34    77
# Comp:  2           [NII]6583_d      1.182       1.3      44     1
# -----------------------------------------------------------------
# pPXF fit done in 2.86 s
# PIXEL: 186
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -818       393
#  comp.  1:       -20         6
#  comp.  2:        59         1
# chi2/DOF: 0.2411; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 192; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.8502       1.0     -20     6
# Comp:  2           [NII]6583_d      1.157       1.3      59     1
# -----------------------------------------------------------------
# pPXF fit done in 1.98 s
# PIXEL: 187
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -682       445
#  comp.  1:        13        51
#  comp.  2:        37         1
# chi2/DOF: 0.1896; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 194; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.8521       1.1      13    51
# Comp:  2           [NII]6583_d     0.9483       1.3      37     1
# -----------------------------------------------------------------
# pPXF fit done in 2.40 s
# PIXEL: 188
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -904       292
#  comp.  1:        58         1
#  comp.  2:        80         1
# chi2/DOF: 0.2071; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 174; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.204       1.0      58     1
# Comp:  2           [NII]6583_d     0.9398       1.3      80     1
# -----------------------------------------------------------------
# pPXF fit done in 2.85 s
# PIXEL: 189
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000      1000
#  comp.  1:        57        45
#  comp.  2:        69        80
# chi2/DOF: 0.4093; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 175; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.847       1.1      57    45
# Comp:  2           [NII]6583_d      1.286       1.5      69    80
# -----------------------------------------------------------------
# pPXF fit done in 2.68 s
# PIXEL: 190
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1911      1000
#  comp.  1:        47        46
#  comp.  2:        66       103
# chi2/DOF: 0.4370; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 17; Func calls: 298; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.226       1.1      47    46
# Comp:  2           [NII]6583_d      1.564       1.5      66   103
# -----------------------------------------------------------------
# pPXF fit done in 4.10 s
# PIXEL: 191
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       913       523
#  comp.  1:        60        75
#  comp.  2:        61       122
# chi2/DOF: 0.4761; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.725       1.1      60    75
# Comp:  2           [NII]6583_d      2.084       1.5      61   122
# -----------------------------------------------------------------
# pPXF fit done in 3.09 s
# PIXEL: 192
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       922       522
#  comp.  1:        59        89
#  comp.  2:        80       139
# chi2/DOF: 0.5136; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 172; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.223       1.0      59    89
# Comp:  2           [NII]6583_d      2.400       1.4      80   139
# -----------------------------------------------------------------
# pPXF fit done in 2.36 s
# PIXEL: 193
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       676       711
#  comp.  1:        62       108
#  comp.  2:        37       147
# chi2/DOF: 0.4900; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 172; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.617      0.91      62   108
# Comp:  2           [NII]6583_d      2.551       1.2      37   147
# -----------------------------------------------------------------
# pPXF fit done in 2.74 s
# PIXEL: 194
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -215       372
#  comp.  1:        52       110
#  comp.  2:        45       116
# chi2/DOF: 0.4096; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 16; Func calls: 277; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.953      0.73      52   110
# Comp:  2           [NII]6583_d      2.296      0.93      45   116
# -----------------------------------------------------------------
# pPXF fit done in 3.65 s
# PIXEL: 195
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -274       330
#  comp.  1:        60       106
#  comp.  2:        53       121
# chi2/DOF: 0.4801; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 155; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.254      0.68      60   106
# Comp:  2           [NII]6583_d      2.397      0.88      53   121
# -----------------------------------------------------------------
# pPXF fit done in 1.75 s
# PIXEL: 196
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       307      1000
#  comp.  1:        68        93
#  comp.  2:        54       135
# chi2/DOF: 0.4510; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.554      0.51      68    93
# Comp:  2           [NII]6583_d      2.711      0.71      54   135
# -----------------------------------------------------------------
# pPXF fit done in 2.15 s
# PIXEL: 197
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -317       888
#  comp.  1:        64        97
#  comp.  2:        50       117
# chi2/DOF: 0.5690; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.834      0.53      64    97
# Comp:  2           [NII]6583_d      2.738      0.70      50   117
# -----------------------------------------------------------------
# pPXF fit done in 1.45 s
# PIXEL: 198
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -247      1000
#  comp.  1:        52        97
#  comp.  2:        72       106
# chi2/DOF: 0.6146; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.058      0.57      52    97
# Comp:  2           [NII]6583_d      2.830      0.74      72   106
# -----------------------------------------------------------------
# pPXF fit done in 1.91 s
# PIXEL: 199
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -628      1000
#  comp.  1:        62        97
#  comp.  2:        87       107
# chi2/DOF: 0.6449; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.086      0.63      62    97
# Comp:  2           [NII]6583_d      2.962      0.81      87   107
# -----------------------------------------------------------------
# pPXF fit done in 2.39 s
# PIXEL: 200
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -994        80
#  comp.  1:        57       109
#  comp.  2:        52        73
# chi2/DOF: 0.6881; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 190; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.663      0.73      57   109
# Comp:  2           [NII]6583_d      2.772      0.86      52    73
# -----------------------------------------------------------------
# pPXF fit done in 2.48 s
# PIXEL: 201
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1050         1
#  comp.  1:        49       122
#  comp.  2:        64        80
# chi2/DOF: 0.6471; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.394       1.1      49   122
# Comp:  2           [NII]6583_d      2.990       1.3      64    80
# -----------------------------------------------------------------
# pPXF fit done in 2.06 s
# PIXEL: 202
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -937       214
#  comp.  1:        57       128
#  comp.  2:        79        76
# chi2/DOF: 0.6405; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.551       1.4      57   128
# Comp:  2           [NII]6583_d      2.777       1.5      79    76
# -----------------------------------------------------------------
# pPXF fit done in 1.76 s
# PIXEL: 203
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -865       170
#  comp.  1:        91       119
#  comp.  2:        90        83
# chi2/DOF: 0.6247; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.297       1.5      91   119
# Comp:  2           [NII]6583_d      2.595       1.7      90    83
# -----------------------------------------------------------------
# pPXF fit done in 1.30 s
# PIXEL: 204
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -891       141
#  comp.  1:        90       124
#  comp.  2:        93        65
# chi2/DOF: 0.6532; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# ...
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       728       474
#  comp.  1:        73         1
#  comp.  2:       264         1
# chi2/DOF: 0.8335; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.160       6.5      73     1
# Comp:  2           [NII]6583_d      1.244       8.2     264     1
# -----------------------------------------------------------------
# pPXF fit done in 1.01 s
# PIXEL: 230
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -176         1
#  comp.  1:        80         1
#  comp.  2:       244         1
# chi2/DOF: 0.8567; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.473       7.9      80     1
# Comp:  2           [NII]6583_d      1.423       10.     244     1
# -----------------------------------------------------------------
# pPXF fit done in 1.03 s
# PIXEL: 231
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000         1
#  comp.  1:       133         1
#  comp.  2:        -0       200
# chi2/DOF: 0.9100; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.686       11.     133     1
# Comp:  2           [NII]6583_d      0.000       19.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.80 s
# PIXEL: 232
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -370         1
#  comp.  1:        12         1
#  comp.  2:        92       263
# chi2/DOF: 0.9398; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.322       11.      12     1
# Comp:  2           [NII]6583_d      0.000       22.      92   263
# -----------------------------------------------------------------
# pPXF fit done in 1.45 s
# PIXEL: 233
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       648         1
#  comp.  1:       -70         1
#  comp.  2:         0       200
# chi2/DOF: 0.8243; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.6198       12.     -70     1
# Comp:  2           [NII]6583_d      0.000       21.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.96 s
# PIXEL: 234
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000      1000
#  comp.  1:       -83         1
#  comp.  2:       115         5
# chi2/DOF: 0.8211; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.7141       11.     -83     1
# Comp:  2           [NII]6583_d      2.712       13.     115     5
# -----------------------------------------------------------------
# pPXF fit done in 1.73 s
# PIXEL: 235
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1946         1
#  comp.  1:       868       380
#  comp.  2:        83         1
# chi2/DOF: 0.8209; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       22.     868   380
# Comp:  2           [NII]6583_d      2.542       15.      83     1
# -----------------------------------------------------------------
# pPXF fit done in 1.19 s
# PIXEL: 236
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       166         1
#  comp.  1:        12       103
#  comp.  2:        22         1
# chi2/DOF: 0.8172; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.3315       7.9      12   103
# Comp:  2           [NII]6583_d      2.848       8.7      22     1
# -----------------------------------------------------------------
# pPXF fit done in 1.45 s
# PIXEL: 237
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1216         1
#  comp.  1:        84       102
#  comp.  2:        31       213
# chi2/DOF: 0.5680; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       9.8      84   102
# Comp:  2           [NII]6583_d      2.839       15.      31   213
# -----------------------------------------------------------------
# pPXF fit done in 1.30 s
# PIXEL: 238
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1747         1
#  comp.  1:       -18       159
#  comp.  2:        76       217
# chi2/DOF: 0.5202; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       11.     -18   159
# Comp:  2           [NII]6583_d      5.833       16.      76   217
# -----------------------------------------------------------------
# pPXF fit done in 1.49 s
# PIXEL: 239
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -536         1
#  comp.  1:         9       227
#  comp.  2:        10       224
# chi2/DOF: 0.4716; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       14.       9   227
# Comp:  2           [NII]6583_d      8.132       18.      10   224
# -----------------------------------------------------------------
# pPXF fit done in 1.68 s
# PIXEL: 240
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1414         1
#  comp.  1:        -0       200
#  comp.  2:       -26       326
# chi2/DOF: 0.5066; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       17.      -0   200
# Comp:  2           [NII]6583_d      13.88       26.     -26   326
# -----------------------------------------------------------------
# pPXF fit done in 1.66 s
# PIXEL: 241
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -608      1000
#  comp.  1:       -33       307
#  comp.  2:       -81       423
# chi2/DOF: 0.6149; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha    0.01915       19.     -33   307
# Comp:  2           [NII]6583_d      8.351       28.     -81   423
# -----------------------------------------------------------------
# pPXF fit done in 1.73 s
# PIXEL: 242
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -456         1
#  comp.  1:        -0       201
#  comp.  2:        -5       207
# chi2/DOF: 0.7801; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 177; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       13.      -0   201
# Comp:  2           [NII]6583_d      0.000       16.      -5   207
# -----------------------------------------------------------------
# pPXF fit done in 1.86 s
# PIXEL: 243
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -414         1
#  comp.  1:        -0       200
#  comp.  2:         3       211
# chi2/DOF: 0.8535; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       16.      -0   200
# Comp:  2           [NII]6583_d      3.977       21.       3   211
# -----------------------------------------------------------------
# pPXF fit done in 1.92 s
# PIXEL: 244
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -409      1000
#  comp.  1:         0       200
#  comp.  2:       -19       248
# chi2/DOF: 0.9201; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       15.       0   200
# Comp:  2           [NII]6583_d      0.000       21.     -19   248
# -----------------------------------------------------------------
# pPXF fit done in 1.02 s
# PIXEL: 245
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -389         1
#  comp.  1:         0       200
#  comp.  2:        -0       200
# chi2/DOF: 0.7166; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 161; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       12.       0   200
# Comp:  2           [NII]6583_d      0.000       15.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 2.96 s
# PIXEL: 246
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1134         1
#  comp.  1:        -0       200
#  comp.  2:        45         1
# chi2/DOF: 0.8618; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       15.      -0   200
# Comp:  2           [NII]6583_d      4.865       13.      45     1
# -----------------------------------------------------------------
# pPXF fit done in 2.76 s
# PIXEL: 247

# %%
# raw.shape == (n_wave, n_spatial)
spatial_flux = raw.sum(axis=0)       # total flux in each slit column
slit_pixels  = np.arange(raw.shape[1])

# Only look between 150 and 250
search_range = slice(150, 251)
peak_rel = np.argmax(spatial_flux[search_range])
peak = slit_pixels[search_range][peak_rel]

print(f"Peak flux at {peak} px")

plt.figure(figsize=(8, 4))
plt.axvline(peak, color='green', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
plt.axvline(175, color='red', linestyle='--', linewidth=1)
plt.axvline(215, color='red', linestyle='--', linewidth=1)
plt.scatter(slit_pixels, spatial_flux, s=10)
plt.xlabel("Slit Pixel")
plt.ylabel("Integrated Flux")
plt.title("Flux vs. Slit Position")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Peak flux at 196 px

# %%
for center, df_rb, pp in results[25:100]:
    # Ensure the function can access 'lam'
    lam_array = df_rb['lam'].values
    plot_ppxf.__globals__['lam'] = lam_array

    print(f"Window centre: {center}")
    plot_ppxf(df_rb, pp)

    # Extract and print the Hα sigma (km/s)
    sigma = pp.sol[1][1]
    print(f"σ (km/s): {sigma:.2f}\n")
# Out:
# Window centre: 177
# σ (km/s): 64.64
#
# Window centre: 178
# σ (km/s): 65.56
#
# Window centre: 179
# σ (km/s): 1.03
#
# Window centre: 180
# σ (km/s): 52.91
#
# Window centre: 181
# σ (km/s): 1.03
#
# Window centre: 182
# σ (km/s): 200.71
#
# Window centre: 183
# σ (km/s): 143.17
#
# Window centre: 184
# σ (km/s): 75.61
#
# Window centre: 185
# σ (km/s): 120.16
#
# Window centre: 186
# σ (km/s): 77.13
#
# Window centre: 187
# σ (km/s): 6.01
#
# Window centre: 188
# σ (km/s): 50.77
#
# Window centre: 189
# σ (km/s): 1.03
#
# Window centre: 190
# σ (km/s): 45.08
#
# Window centre: 191
# σ (km/s): 45.95
#
# Window centre: 192
# σ (km/s): 74.67
#
# Window centre: 193
# σ (km/s): 89.14
#
# Window centre: 194
# σ (km/s): 107.54
#
# Window centre: 195
# σ (km/s): 110.07
#
# Window centre: 196
# σ (km/s): 106.31
#
# Window centre: 197
# σ (km/s): 92.70
#
# Window centre: 198
# σ (km/s): 96.77
#
# Window centre: 199
# σ (km/s): 96.52
#
# Window centre: 200
# σ (km/s): 96.94
#
# Window centre: 201
# σ (km/s): 109.49
#
# Window centre: 202
# σ (km/s): 122.15
#
# Window centre: 203
# σ (km/s): 127.71
#
# Window centre: 204
# σ (km/s): 118.72
#
# Window centre: 205
# σ (km/s): 124.13
#
# Window centre: 206
# σ (km/s): 124.91
#
# Window centre: 207
# σ (km/s): 118.95
#
# Window centre: 208
# σ (km/s): 94.89
#
# Window centre: 209
# σ (km/s): 89.56
#
# Window centre: 210
# σ (km/s): 91.23
#
# Window centre: 211
# σ (km/s): 89.43
#
# Window centre: 212
# σ (km/s): 51.56
#
# Window centre: 213
# σ (km/s): 95.06
#
# Window centre: 214
# σ (km/s): 55.41
#
# Window centre: 215
# σ (km/s): 1.03
#
# Window centre: 216
# σ (km/s): 60.09
#
# Window centre: 217
# σ (km/s): 112.06
#
# Window centre: 218
# σ (km/s): 1.03
#
# Window centre: 219
# σ (km/s): 118.06
#
# Window centre: 220
# σ (km/s): 87.97
#
# Window centre: 221
# σ (km/s): 168.52
#
# Window centre: 222
# σ (km/s): 50.12
#
# Window centre: 223
# σ (km/s): 161.53
#
# Window centre: 224
# σ (km/s): 77.61
#
# Window centre: 225
# σ (km/s): 82.88
#
# Window centre: 226
# σ (km/s): 62.51
#
# Window centre: 227
# σ (km/s): 5.21
#
# Window centre: 228
# σ (km/s): 6.09
#
# Window centre: 229
# σ (km/s): 75.28
#
# Window centre: 230
# σ (km/s): 1.03
#
# Window centre: 231
# σ (km/s): 1.03
#
# Window centre: 232
# σ (km/s): 1.03
#
# Window centre: 233
# σ (km/s): 1.03
#
# Window centre: 234
# σ (km/s): 1.03
#
# Window centre: 235
# σ (km/s): 1.03
#
# Window centre: 236
# σ (km/s): 379.90
#
# Window centre: 237
# σ (km/s): 103.30
#
# Window centre: 238
# σ (km/s): 101.88
#
# Window centre: 239
# σ (km/s): 159.13
#
# Window centre: 240
# σ (km/s): 226.66
#
# Window centre: 241
# σ (km/s): 200.00
#
# Window centre: 242
# σ (km/s): 306.92
#
# Window centre: 243
# σ (km/s): 200.88
#
# Window centre: 244
# σ (km/s): 200.00
#
# Window centre: 245
# σ (km/s): 200.00
#
# Window centre: 246
# σ (km/s): 200.00
#
# Window centre: 247
# σ (km/s): 200.00

# %%
centers     = []
velocities  = []; v_errs     = []
dispersions = []; sigma_errs = []
EWs         = []; EW_errs    = []

for center, _, pp in results:
    # --- extract Hα kinematics from the list ---
    sol_gas    = pp.sol[1]
    err_gas    = pp.error[1]
    v_ha, sigma_ha       = sol_gas
    #sigma = np.sqrt(sigma_inst**2 + sigma_ha**2)

    v_ha_err, sigma_ha_err = err_gas

    # find Hα in gas_names (should be idx 0 here)
    idx = np.where(pp.gas_names == "Halpha")[0][0]

    # compute flux, continuum & EW as before
    flux_ha   = pp.gas_flux[idx]
    continuum = pp.bestfit - pp.gas_bestfit
    peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
    cont0     = continuum[peak_i]
    cont_err  = pp.noise[peak_i]
    flux_err  = pp.gas_flux_error[idx]

    EW        = flux_ha / cont0
    EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

    # store
    centers.append(center)
    velocities.append(v_ha)
    v_errs.append(v_ha_err)
    dispersions.append(sigma_ha)
    sigma_errs.append(sigma_ha_err)
    EWs.append(EW)
    EW_errs.append(EW_err)
# Out:
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_35604/3518839896.py:27: RuntimeWarning: divide by zero encountered in scalar divide
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_35604/3518839896.py:27: RuntimeWarning: invalid value encountered in scalar multiply
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

# %%
fig, axs = plt.subplots(3,1,figsize=(10,9),sharex=True)

colors = ['#1f77b4', '#2ca02c', '#d62728']  # blue, green, red


# Velocity
axs[0].errorbar(centers, velocities, yerr=v_errs,
                fmt='o', ecolor=colors[0], color=colors[0],
                capsize=3, label='Hα Velocity')
axs[0].set_ylabel("Velocity (km/s)")
axs[0].set_title("Hα Velocity vs. Slit Position")
axs[0].axvline(175, color='red', ls='--', lw=1)
axs[0].axvline(215, color='red', ls='--', lw=1)
axs[0].legend(); axs[0].grid(True)

# Dispersion
axs[1].errorbar(centers, dispersions, yerr=sigma_errs,
                fmt='o', ecolor=colors[1], color=colors[1],
                capsize=3, label='Hα σ')
axs[1].set_ylim(-100,500)
axs[1].set_ylabel("σ (km/s)")
axs[1].set_title("Hα σ vs. Slit Position")
axs[1].axvline(175, color='red', ls='--', lw=1)
axs[1].axvline(215, color='red', ls='--', lw=1)
axs[1].legend(); axs[1].grid(True)

# Equivalent Width
axs[2].errorbar(centers, EWs, yerr = EW_errs,
                fmt='o', ecolor=colors[2], color=colors[2],
                capsize=3, label='Hα EW')
axs[2].set_ylabel("EW (Å)")
axs[2].set_xlabel("Slit Position (arcsec)")
axs[2].set_title("Hα EW vs. Slit Position")
axs[2].axvline(175, color='red', ls='--', lw=1)
axs[2].axvline(215, color='red', ls='--', lw=1)
axs[2].legend(); axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame({
    'center':        centers,
    'velocity':      velocities,
    'velocity_err':  v_errs,
    'dispersion':    dispersions,
    'dispersion_err': sigma_errs,
    'EW':            EWs,
    'EW_err':        EW_errs
})

# Save to CSV
df.to_csv('../halpha results/WB2_orth_halpha_results.csv', index=False)
