# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,
)

# %%
raw = np.load("../calibrated data/WB2_data.npy")       # rename your 2D array
waveem = np.load("../calibrated data/WB2_waveem.npy")

window_size = 5
step        = 1
scale       = 0.4   # arcsec per pixel

pix_min, pix_max = 150, 250   
results = []
raw_roi = raw[:, pix_min:pix_max]

for start in range(0, raw_roi.shape[1] - window_size + 1, step):
    end = start + window_size
    spectrum = raw_roi[:, start:end].sum(axis=1)

    # Build DataFrame for this spectrum
    df_spec = pd.DataFrame({
        "waveem": waveem,
        "flux":   spectrum
    })

    # Process, rebin, and run pPXF
    df_cut = process_spectrum(df_spec)
    noise = make_noise(df_cut)
    df_rb, lam, flux_rb, ln_w = rebin_to_log(df_cut)
    velscale, fwhm = calculate_velscale_fwhm(ln_w, lam)
    pp, gas_templates = run_ppxf(lam, fwhm, velscale, df_rb, noise)

    # Compute global center index
    center = start + window_size//2 + pix_min
    print(f'PIXEL: {center}')

    # Store center, rebinned DataFrame, and fit result
    results.append((center, df_rb, pp))
# Out:
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       362         1
#  comp.  1:       251      1000
#  comp.  2:         0       200
# chi2/DOF: 0.7409; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 155; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       8.3     251  1000
# Comp:  2           [NII]6583_d      0.000       5.1       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.77 s
# PIXEL: 152
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1343        29
#  comp.  1:       -12       285
#  comp.  2:        17       196
# chi2/DOF: 0.8174; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 244; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.874       3.1     -12   285
# Comp:  2           [NII]6583_d      0.000       3.4      17   196
# -----------------------------------------------------------------
# pPXF fit done in 2.90 s
# PIXEL: 153
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       346         1
#  comp.  1:         5       247
#  comp.  2:        17       175
# chi2/DOF: 0.6953; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.322       3.6       5   247
# Comp:  2           [NII]6583_d     0.3144       4.0      17   175
# -----------------------------------------------------------------
# pPXF fit done in 2.64 s
# PIXEL: 154
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -282       416
#  comp.  1:        29        99
#  comp.  2:        -1       195
# chi2/DOF: 0.6994; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.339       2.7      29    99
# Comp:  2           [NII]6583_d     0.9380       4.2      -1   195
# -----------------------------------------------------------------
# pPXF fit done in 1.94 s
# PIXEL: 155
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -29       283
#  comp.  1:       -14       103
#  comp.  2:       -19       205
# chi2/DOF: 0.6429; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 244; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.178       2.4     -14   103
# Comp:  2           [NII]6583_d     0.7657       3.7     -19   205
# -----------------------------------------------------------------
# pPXF fit done in 3.98 s
# PIXEL: 156
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       165       193
#  comp.  1:        -2       102
#  comp.  2:       -13       154
# chi2/DOF: 0.5545; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.463       2.0      -2   102
# Comp:  2           [NII]6583_d     0.5426       2.9     -13   154
# -----------------------------------------------------------------
# pPXF fit done in 2.72 s
# PIXEL: 157
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       432       623
#  comp.  1:       -67       112
#  comp.  2:        14       104
# chi2/DOF: 0.5355; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.200       1.9     -67   112
# Comp:  2           [NII]6583_d     0.8523       2.3      14   104
# -----------------------------------------------------------------
# pPXF fit done in 2.39 s
# PIXEL: 158
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -20      1000
#  comp.  1:       -20        84
#  comp.  2:        59         1
# chi2/DOF: 0.5389; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.705       1.3     -20    84
# Comp:  2           [NII]6583_d      1.300       1.4      59     1
# -----------------------------------------------------------------
# pPXF fit done in 1.04 s
# PIXEL: 159
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1106      1000
#  comp.  1:       -37        97
#  comp.  2:        65        11
# chi2/DOF: 0.4812; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 193; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.014       1.2     -37    97
# Comp:  2           [NII]6583_d      1.216       1.3      65    11
# -----------------------------------------------------------------
# pPXF fit done in 4.51 s
# PIXEL: 160
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       164      1000
#  comp.  1:       -31       137
#  comp.  2:        77        53
# chi2/DOF: 0.4622; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 93; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.842       1.2     -31   137
# Comp:  2           [NII]6583_d      1.782       1.3      77    53
# -----------------------------------------------------------------
# pPXF fit done in 1.21 s
# PIXEL: 161
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1499      1000
#  comp.  1:       -12        70
#  comp.  2:        61        71
# chi2/DOF: 0.4503; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.125       1.1     -12    70
# Comp:  2           [NII]6583_d      2.128       1.4      61    71
# -----------------------------------------------------------------
# pPXF fit done in 1.33 s
# PIXEL: 162
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1096      1000
#  comp.  1:         5        62
#  comp.  2:        69        10
# chi2/DOF: 0.4359; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.263       1.1       5    62
# Comp:  2           [NII]6583_d      2.037       1.3      69    10
# -----------------------------------------------------------------
# pPXF fit done in 1.01 s
# PIXEL: 163
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1257       960
#  comp.  1:         7        71
#  comp.  2:        83         8
# chi2/DOF: 0.4379; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.135       1.0       7    71
# Comp:  2           [NII]6583_d      1.705       1.2      83     8
# -----------------------------------------------------------------
# pPXF fit done in 1.22 s
# PIXEL: 164
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       450       987
#  comp.  1:        18        81
#  comp.  2:        78        46
# chi2/DOF: 0.4428; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.226      0.99      18    81
# Comp:  2           [NII]6583_d      2.014       1.2      78    46
# -----------------------------------------------------------------
# pPXF fit done in 1.16 s
# PIXEL: 165
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       812       707
#  comp.  1:        30        78
#  comp.  2:        85        62
# chi2/DOF: 0.4478; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 139; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.325      0.84      30    78
# Comp:  2           [NII]6583_d      2.307       1.0      85    62
# -----------------------------------------------------------------
# pPXF fit done in 1.33 s
# PIXEL: 166
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       214      1000
#  comp.  1:        15       108
#  comp.  2:        76        48
# chi2/DOF: 0.4545; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.924      0.80      15   108
# Comp:  2           [NII]6583_d      2.179      0.91      76    48
# -----------------------------------------------------------------
# pPXF fit done in 1.29 s
# PIXEL: 167
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1093        90
#  comp.  1:        28        83
#  comp.  2:        91        67
# chi2/DOF: 0.4592; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 240; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.771      0.75      28    83
# Comp:  2           [NII]6583_d      2.491      0.91      91    67
# -----------------------------------------------------------------
# pPXF fit done in 3.32 s
# PIXEL: 168
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1225       323
#  comp.  1:        17       108
#  comp.  2:        68        72
# chi2/DOF: 0.5111; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 329; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.603      0.79      17   108
# Comp:  2           [NII]6583_d      2.491      0.93      68    72
# -----------------------------------------------------------------
# pPXF fit done in 2.78 s
# PIXEL: 169
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       985       700
#  comp.  1:        32        95
#  comp.  2:        46         1
# chi2/DOF: 0.4691; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.704       1.0      32    95
# Comp:  2           [NII]6583_d      1.844       1.2      46     1
# -----------------------------------------------------------------
# pPXF fit done in 1.38 s
# PIXEL: 170
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        24        49
#  comp.  1:        18       103
#  comp.  2:        35         1
# chi2/DOF: 0.4880; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.274       2.0      18   103
# Comp:  2           [NII]6583_d      1.210       2.2      35     1
# -----------------------------------------------------------------
# pPXF fit done in 0.63 s
# PIXEL: 171
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        68       105
#  comp.  1:        25        98
#  comp.  2:        51         1
# chi2/DOF: 0.4939; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.193       1.9      25    98
# Comp:  2           [NII]6583_d      1.326       2.2      51     1
# -----------------------------------------------------------------
# pPXF fit done in 1.40 s
# PIXEL: 172
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        28        43
#  comp.  1:        34        92
#  comp.  2:        50         1
# chi2/DOF: 0.4954; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.955       1.8      34    92
# Comp:  2           [NII]6583_d      1.553       2.1      50     1
# -----------------------------------------------------------------
# pPXF fit done in 0.92 s
# PIXEL: 173
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -604      1000
#  comp.  1:        47        64
#  comp.  2:        69         1
# chi2/DOF: 0.4940; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 174; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.941       1.7      47    64
# Comp:  2           [NII]6583_d      1.195       2.0      69     1
# -----------------------------------------------------------------
# pPXF fit done in 2.27 s
# PIXEL: 174
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -447       867
#  comp.  1:        39        85
#  comp.  2:        52         1
# chi2/DOF: 0.4871; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.289       1.5      39    85
# Comp:  2           [NII]6583_d      1.506       1.7      52     1
# -----------------------------------------------------------------
# pPXF fit done in 1.81 s
# PIXEL: 175
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       162      1000
#  comp.  1:        40        88
#  comp.  2:        56         1
# chi2/DOF: 0.4503; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.447      0.59      40    88
# Comp:  2           [NII]6583_d      1.601      0.67      56     1
# -----------------------------------------------------------------
# pPXF fit done in 1.57 s
# PIXEL: 176
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       132      1000
#  comp.  1:        38        66
#  comp.  2:        29         1
# chi2/DOF: 0.4453; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.133      0.55      38    66
# Comp:  2           [NII]6583_d      1.631      0.65      29     1
# -----------------------------------------------------------------
# pPXF fit done in 2.10 s
# PIXEL: 177
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       112       335
#  comp.  1:        22        90
#  comp.  2:         6         1
# chi2/DOF: 0.5311; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.648      0.77      22    90
# Comp:  2           [NII]6583_d      1.495      0.87       6     1
# -----------------------------------------------------------------
# pPXF fit done in 0.96 s
# PIXEL: 178
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       612      1000
#  comp.  1:        10        80
#  comp.  2:       -17         1
# chi2/DOF: 0.5785; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.064      0.89      10    80
# Comp:  2           [NII]6583_d      1.870       1.0     -17     1
# -----------------------------------------------------------------
# pPXF fit done in 1.11 s
# PIXEL: 179
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        66      1000
#  comp.  1:       -10        97
#  comp.  2:        11         1
# chi2/DOF: 0.5763; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.249      0.91     -10    97
# Comp:  2           [NII]6583_d      1.668       1.0      11     1
# -----------------------------------------------------------------
# pPXF fit done in 1.59 s
# PIXEL: 180
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -707      1000
#  comp.  1:       -12       102
#  comp.  2:        21        27
# chi2/DOF: 0.5516; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 139; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.255      0.89     -12   102
# Comp:  2           [NII]6583_d      1.973       1.0      21    27
# -----------------------------------------------------------------
# pPXF fit done in 1.57 s
# PIXEL: 181
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -674      1000
#  comp.  1:        -5       103
#  comp.  2:        33        55
# chi2/DOF: 0.5427; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.212      0.87      -5   103
# Comp:  2           [NII]6583_d      1.668       1.0      33    55
# -----------------------------------------------------------------
# pPXF fit done in 0.94 s
# PIXEL: 182
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1009       533
#  comp.  1:         1        89
#  comp.  2:        61        27
# chi2/DOF: 0.3640; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.607      0.60       1    89
# Comp:  2           [NII]6583_d      1.571      0.69      61    27
# -----------------------------------------------------------------
# pPXF fit done in 1.12 s
# PIXEL: 183
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1168       335
#  comp.  1:        26        91
#  comp.  2:        98         1
# chi2/DOF: 0.2992; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 259; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.252      0.54      26    91
# Comp:  2           [NII]6583_d      1.342      0.60      98     1
# -----------------------------------------------------------------
# pPXF fit done in 2.57 s
# PIXEL: 184
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -997       775
#  comp.  1:        59        85
#  comp.  2:       108        14
# chi2/DOF: 0.4619; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.123      0.64      59    85
# Comp:  2           [NII]6583_d      1.380      0.73     108    14
# -----------------------------------------------------------------
# pPXF fit done in 2.19 s
# PIXEL: 185
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -950       638
#  comp.  1:        84        60
#  comp.  2:       110        14
# chi2/DOF: 0.4861; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.953      0.61      84    60
# Comp:  2           [NII]6583_d      1.266      0.73     110    14
# -----------------------------------------------------------------
# pPXF fit done in 1.67 s
# PIXEL: 186
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -684       935
#  comp.  1:        98        59
#  comp.  2:       119        59
# chi2/DOF: 0.4821; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.919      0.57      98    59
# Comp:  2           [NII]6583_d      1.673      0.72     119    59
# -----------------------------------------------------------------
# pPXF fit done in 1.87 s
# PIXEL: 187
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -407      1000
#  comp.  1:       119        25
#  comp.  2:       131        75
# chi2/DOF: 0.4900; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.021      0.52     119    25
# Comp:  2           [NII]6583_d      1.857      0.71     131    75
# -----------------------------------------------------------------
# pPXF fit done in 1.65 s
# PIXEL: 188
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -465       898
#  comp.  1:       129         1
#  comp.  2:       117        66
# chi2/DOF: 0.5140; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.090      0.48     129     1
# Comp:  2           [NII]6583_d      1.975      0.65     117    66
# -----------------------------------------------------------------
# pPXF fit done in 1.60 s
# PIXEL: 189
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -321       877
#  comp.  1:       130         1
#  comp.  2:       107        56
# chi2/DOF: 0.3935; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.148      0.37     130     1
# Comp:  2           [NII]6583_d      2.098      0.50     107    56
# -----------------------------------------------------------------
# pPXF fit done in 0.91 s
# PIXEL: 190
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        79       913
#  comp.  1:       136         1
#  comp.  2:       114        45
# chi2/DOF: 0.6619; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.268      0.48     136     1
# Comp:  2           [NII]6583_d      2.230      0.63     114    45
# -----------------------------------------------------------------
# pPXF fit done in 1.35 s
# PIXEL: 191
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        40       918
#  comp.  1:       137         1
#  comp.  2:        99        51
# chi2/DOF: 0.7247; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.430      0.48     137     1
# Comp:  2           [NII]6583_d      2.310      0.64      99    51
# -----------------------------------------------------------------
# pPXF fit done in 1.00 s
# PIXEL: 192
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -53       863
#  comp.  1:       143         1
#  comp.  2:        93        24
# chi2/DOF: 0.7759; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.552      0.48     143     1
# Comp:  2           [NII]6583_d      2.294      0.62      93    24
# -----------------------------------------------------------------
# pPXF fit done in 1.08 s
# PIXEL: 193
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       264       980
#  comp.  1:       139        11
#  comp.  2:        94        43
# chi2/DOF: 0.8091; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.534      0.51     139    11
# Comp:  2           [NII]6583_d      2.273      0.66      94    43
# -----------------------------------------------------------------
# pPXF fit done in 2.12 s
# PIXEL: 194
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -225       799
#  comp.  1:       145        11
#  comp.  2:        97         1
# chi2/DOF: 0.7803; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.443      0.59     145    11
# Comp:  2           [NII]6583_d      2.165      0.74      97     1
# -----------------------------------------------------------------
# pPXF fit done in 1.27 s
# PIXEL: 195
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -165         1
#  comp.  1:       121        69
#  comp.  2:       120         1
# chi2/DOF: 0.9191; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.674       1.2     121    69
# Comp:  2           [NII]6583_d      2.197       1.4     120     1
# -----------------------------------------------------------------
# pPXF fit done in 1.35 s
# PIXEL: 196
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000      1000
#  comp.  1:       147         1
#  comp.  2:       140         1
# chi2/DOF: 0.9370; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 194; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.498       1.3     147     1
# Comp:  2           [NII]6583_d      1.725       1.7     140     1
# -----------------------------------------------------------------
# pPXF fit done in 2.15 s
# PIXEL: 197
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -815       832
#  comp.  1:       134        10
#  comp.  2:       151         1
# chi2/DOF: 0.9427; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.733       1.4     134    10
# Comp:  2           [NII]6583_d      2.254       1.8     151     1
# -----------------------------------------------------------------
# pPXF fit done in 1.46 s
# PIXEL: 198
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -247      1000
#  comp.  1:       130        68
#  comp.  2:       153        30
# chi2/DOF: 0.9359; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.371       1.6     130    68
# Comp:  2           [NII]6583_d      2.829       1.9     153    30
# -----------------------------------------------------------------
# pPXF fit done in 0.97 s
# PIXEL: 199
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -187         1
#  comp.  1:       102       103
#  comp.  2:       191         1
# chi2/DOF: 0.9069; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.261       1.7     102   103
# Comp:  2           [NII]6583_d      2.396       1.9     191     1
# -----------------------------------------------------------------
# pPXF fit done in 1.35 s
# PIXEL: 200
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       735      1000
#  comp.  1:       136        58
#  comp.  2:       171        27
# chi2/DOF: 0.7009; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 230; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.355      0.56     136    58
# Comp:  2           [NII]6583_d      2.153      0.69     171    27
# -----------------------------------------------------------------
# pPXF fit done in 2.12 s
# PIXEL: 201
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       245       450
#  comp.  1:       143        95
#  comp.  2:       159         1
# chi2/DOF: 0.7800; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.809      0.67     143    95
# Comp:  2           [NII]6583_d      2.388      0.75     159     1
# -----------------------------------------------------------------
# pPXF fit done in 1.17 s
# PIXEL: 202
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       336       347
#  comp.  1:       153       119
#  comp.  2:       141         1
# chi2/DOF: 0.7493; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.561      0.73     153   119
# Comp:  2           [NII]6583_d      1.935      0.77     141     1
# -----------------------------------------------------------------
# pPXF fit done in 1.60 s
# PIXEL: 203
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       472       349
#  comp.  1:       177       160
#  comp.  2:       160         1
# chi2/DOF: 0.7632; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.223      0.85     177   160
# Comp:  2           [NII]6583_d      1.985      0.84     160     1
# -----------------------------------------------------------------
# pPXF fit done in 1.14 s
# PIXEL: 204
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       446       302
#  comp.  1:       180       164
#  comp.  2:       141        74
# chi2/DOF: 0.7448; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       150       928
#  comp.  1:        32       125
#  comp.  2:       190         1
# chi2/DOF: 0.8641; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 227; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.40       3.0      32   125
# Comp:  2           [NII]6583_d      3.508       3.1     190     1
# -----------------------------------------------------------------
# pPXF fit done in 2.17 s
# PIXEL: 230
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       146         4
#  comp.  1:        50       126
#  comp.  2:       165       103
# chi2/DOF: 0.8012; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      13.00       3.9      50   126
# Comp:  2           [NII]6583_d      4.179       4.7     165   103
# -----------------------------------------------------------------
# pPXF fit done in 1.02 s
# PIXEL: 231
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       179       163
#  comp.  1:        42       121
#  comp.  2:       159         1
# chi2/DOF: 0.7034; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      13.06       3.6      42   121
# Comp:  2           [NII]6583_d      3.161       3.8     159     1
# -----------------------------------------------------------------
# pPXF fit done in 1.40 s
# PIXEL: 232
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       291       152
#  comp.  1:        58       143
#  comp.  2:       118         1
# chi2/DOF: 0.6723; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.96       4.3      58   143
# Comp:  2           [NII]6583_d      3.545       4.3     118     1
# -----------------------------------------------------------------
# pPXF fit done in 1.53 s
# PIXEL: 233
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       259        30
#  comp.  1:        70       142
#  comp.  2:       121         1
# chi2/DOF: 0.6937; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.96       4.4      70   142
# Comp:  2           [NII]6583_d      3.366       4.4     121     1
# -----------------------------------------------------------------
# pPXF fit done in 1.64 s
# PIXEL: 234
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       411       133
#  comp.  1:       108       124
#  comp.  2:       100         1
# chi2/DOF: 0.7047; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 176; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.76       2.8     108   124
# Comp:  2           [NII]6583_d      4.099       3.0     100     1
# -----------------------------------------------------------------
# pPXF fit done in 1.75 s
# PIXEL: 235
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       545        11
#  comp.  1:       127       154
#  comp.  2:        70        84
# chi2/DOF: 0.7300; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.814       2.4     127   154
# Comp:  2           [NII]6583_d      3.094       2.6      70    84
# -----------------------------------------------------------------
# pPXF fit done in 1.10 s
# PIXEL: 236
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       277         1
#  comp.  1:       199       150
#  comp.  2:       133         1
# chi2/DOF: 0.7362; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.669       2.6     199   150
# Comp:  2           [NII]6583_d      3.896       2.6     133     1
# -----------------------------------------------------------------
# pPXF fit done in 2.34 s
# PIXEL: 237
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       330         1
#  comp.  1:       237       260
#  comp.  2:        98         1
# chi2/DOF: 0.7835; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      9.536       3.6     237   260
# Comp:  2           [NII]6583_d      6.708       3.0      98     1
# -----------------------------------------------------------------
# pPXF fit done in 2.07 s
# PIXEL: 238
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1314         1
#  comp.  1:       296       254
#  comp.  2:       101         1
# chi2/DOF: 0.7565; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 176; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.870       4.2     296   254
# Comp:  2           [NII]6583_d      6.878       3.5     101     1
# -----------------------------------------------------------------
# pPXF fit done in 2.10 s
# PIXEL: 239
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       890        28
#  comp.  1:       308       326
#  comp.  2:       712       510
# chi2/DOF: 0.7833; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      9.072       5.5     308   326
# Comp:  2           [NII]6583_d      9.137       8.4     712   510
# -----------------------------------------------------------------
# pPXF fit done in 1.34 s
# PIXEL: 240
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1265         1
#  comp.  1:       386       270
#  comp.  2:      1245       792
# chi2/DOF: 0.7716; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.296       7.2     386   270
# Comp:  2           [NII]6583_d      24.65       14.    1245   792
# -----------------------------------------------------------------
# pPXF fit done in 2.33 s
# PIXEL: 241
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1888         1
#  comp.  1:       292       143
#  comp.  2:        39         1
# chi2/DOF: 0.7675; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 178; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.587       7.2     292   143
# Comp:  2           [NII]6583_d      6.904       7.3      39     1
# -----------------------------------------------------------------
# pPXF fit done in 1.88 s
# PIXEL: 242
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -691       768
#  comp.  1:       127         1
#  comp.  2:         8       210
# chi2/DOF: 0.8867; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.397       10.     127     1
# Comp:  2           [NII]6583_d      0.000       18.       8   210
# -----------------------------------------------------------------
# pPXF fit done in 1.08 s
# PIXEL: 243
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -223         1
#  comp.  1:        94         1
#  comp.  2:        27       203
# chi2/DOF: 1.059; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.073       16.      94     1
# Comp:  2           [NII]6583_d      0.000       28.      27   203
# -----------------------------------------------------------------
# pPXF fit done in 1.28 s
# PIXEL: 244
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -118         1
#  comp.  1:         0       200
#  comp.  2:       161      1000
# chi2/DOF: 1.185; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       48.       0   200
# Comp:  2           [NII]6583_d      0.000   1.1e+02     161  1000
# -----------------------------------------------------------------
# pPXF fit done in 0.92 s
# PIXEL: 245
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1812         1
#  comp.  1:       234         1
#  comp.  2:       290         1
# chi2/DOF: 1.114; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       30.     234     1
# Comp:  2           [NII]6583_d      0.000       37.     290     1
# -----------------------------------------------------------------
# pPXF fit done in 0.87 s
# PIXEL: 246
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -33         1
#  comp.  1:       119         1
#  comp.  2:         0       200
# chi2/DOF: 1.126; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.318       23.     119     1
# Comp:  2           [NII]6583_d      0.000       40.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.17 s
# PIXEL: 247

# %%
# raw.shape == (n_wave, n_spatial)
spatial_flux = raw.sum(axis=0)       # total flux in each slit column
slit_pixels  = np.arange(raw.shape[1])

# Only look between 150 and 250
search_range = slice(150, 251)
peak_rel = np.argmax(spatial_flux[search_range])
peak = slit_pixels[search_range][peak_rel]

print(f"Peak flux at {peak} px")

plt.figure(figsize=(8, 4))
plt.axvline(189, color='green', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
plt.axvline(175, color='red', linestyle='--', linewidth=1)
plt.axvline(215, color='red', linestyle='--', linewidth=1)
plt.scatter(slit_pixels, spatial_flux, s=10)
plt.xlabel("Slit Pixel")
plt.ylabel("Integrated Flux")
plt.title("Flux vs. Slit Position")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Peak flux at 205 px

# %%
for center, df_rb, pp in results[25:100]:
    # Ensure the function can access 'lam'
    lam_array = df_rb['lam'].values
    plot_ppxf.__globals__['lam'] = lam_array

    print(f"Window centre: {center}")
    plot_ppxf(df_rb, pp)

    # Extract and print the Hα sigma (km/s)
    sigma = pp.sol[1][1]
    print(f"σ (km/s): {sigma:.2f}\n")
# Out:
# Window centre: 177
# σ (km/s): 65.66
#
# Window centre: 178
# σ (km/s): 89.86
#
# Window centre: 179
# σ (km/s): 79.56
#
# Window centre: 180
# σ (km/s): 97.19
#
# Window centre: 181
# σ (km/s): 101.89
#
# Window centre: 182
# σ (km/s): 103.40
#
# Window centre: 183
# σ (km/s): 89.13
#
# Window centre: 184
# σ (km/s): 91.06
#
# Window centre: 185
# σ (km/s): 84.54
#
# Window centre: 186
# σ (km/s): 60.25
#
# Window centre: 187
# σ (km/s): 59.26
#
# Window centre: 188
# σ (km/s): 24.66
#
# Window centre: 189
# σ (km/s): 1.03
#
# Window centre: 190
# σ (km/s): 1.03
#
# Window centre: 191
# σ (km/s): 1.03
#
# Window centre: 192
# σ (km/s): 1.03
#
# Window centre: 193
# σ (km/s): 1.03
#
# Window centre: 194
# σ (km/s): 10.74
#
# Window centre: 195
# σ (km/s): 11.39
#
# Window centre: 196
# σ (km/s): 69.28
#
# Window centre: 197
# σ (km/s): 1.03
#
# Window centre: 198
# σ (km/s): 9.75
#
# Window centre: 199
# σ (km/s): 68.20
#
# Window centre: 200
# σ (km/s): 103.02
#
# Window centre: 201
# σ (km/s): 57.68
#
# Window centre: 202
# σ (km/s): 95.43
#
# Window centre: 203
# σ (km/s): 118.79
#
# Window centre: 204
# σ (km/s): 160.42
#
# Window centre: 205
# σ (km/s): 164.21
#
# Window centre: 206
# σ (km/s): 155.57
#
# Window centre: 207
# σ (km/s): 113.67
#
# Window centre: 208
# σ (km/s): 156.38
#
# Window centre: 209
# σ (km/s): 150.96
#
# Window centre: 210
# σ (km/s): 114.61
#
# Window centre: 211
# σ (km/s): 117.12
#
# Window centre: 212
# σ (km/s): 128.00
#
# Window centre: 213
# σ (km/s): 121.82
#
# Window centre: 214
# σ (km/s): 99.76
#
# Window centre: 215
# σ (km/s): 124.96
#
# Window centre: 216
# σ (km/s): 117.87
#
# Window centre: 217
# σ (km/s): 117.76
#
# Window centre: 218
# σ (km/s): 93.69
#
# Window centre: 219
# σ (km/s): 105.88
#
# Window centre: 220
# σ (km/s): 104.11
#
# Window centre: 221
# σ (km/s): 96.61
#
# Window centre: 222
# σ (km/s): 95.90
#
# Window centre: 223
# σ (km/s): 121.07
#
# Window centre: 224
# σ (km/s): 106.23
#
# Window centre: 225
# σ (km/s): 97.32
#
# Window centre: 226
# σ (km/s): 103.85
#
# Window centre: 227
# σ (km/s): 127.27
#
# Window centre: 228
# σ (km/s): 98.06
#
# Window centre: 229
# σ (km/s): 121.31
#
# Window centre: 230
# σ (km/s): 125.32
#
# Window centre: 231
# σ (km/s): 126.34
#
# Window centre: 232
# σ (km/s): 121.37
#
# Window centre: 233
# σ (km/s): 142.91
#
# Window centre: 234
# σ (km/s): 142.11
#
# Window centre: 235
# σ (km/s): 123.94
#
# Window centre: 236
# σ (km/s): 154.30
#
# Window centre: 237
# σ (km/s): 149.60
#
# Window centre: 238
# σ (km/s): 259.87
#
# Window centre: 239
# σ (km/s): 254.40
#
# Window centre: 240
# σ (km/s): 325.72
#
# Window centre: 241
# σ (km/s): 269.97
#
# Window centre: 242
# σ (km/s): 142.56
#
# Window centre: 243
# σ (km/s): 1.45
#
# Window centre: 244
# σ (km/s): 1.03
#
# Window centre: 245
# σ (km/s): 200.00
#
# Window centre: 246
# σ (km/s): 1.03
#
# Window centre: 247
# σ (km/s): 1.03

# %%
centers     = []
velocities  = []; v_errs     = []
dispersions = []; sigma_errs = []
EWs         = []; EW_errs    = []

for center, _, pp in results:
    # --- extract Hα kinematics from the list ---
    sol_gas    = pp.sol[1]
    err_gas    = pp.error[1]
    v_ha, sigma_ha       = sol_gas
    #sigma = np.sqrt(sigma_inst**2 + sigma_ha**2)

    v_ha_err, sigma_ha_err = err_gas

    # find Hα in gas_names (should be idx 0 here)
    idx = np.where(pp.gas_names == "Halpha")[0][0]

    # compute flux, continuum & EW as before
    flux_ha   = pp.gas_flux[idx]
    continuum = pp.bestfit - pp.gas_bestfit
    peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
    cont0     = continuum[peak_i]
    cont_err  = pp.noise[peak_i]
    flux_err  = pp.gas_flux_error[idx]

    EW        = flux_ha / cont0
    EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

    # store
    centers.append(center)
    velocities.append(v_ha)
    v_errs.append(v_ha_err)
    dispersions.append(sigma_ha)
    sigma_errs.append(sigma_ha_err)
    EWs.append(EW)
    EW_errs.append(EW_err)
# Out:
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_28340/3518839896.py:27: RuntimeWarning: divide by zero encountered in scalar divide
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_28340/3518839896.py:27: RuntimeWarning: invalid value encountered in scalar multiply
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

# %%
fig, axs = plt.subplots(3,1,figsize=(10,9),sharex=True)

colors = ['#1f77b4', '#2ca02c', '#d62728']  # blue, green, red


# Velocity
axs[0].errorbar(centers, velocities, yerr=v_errs,
                fmt='o', ecolor=colors[0], color=colors[0],
                capsize=3, label='Hα Velocity')
axs[0].set_ylabel("Velocity (km/s)")
axs[0].set_title("Hα Velocity vs. Slit Position")
axs[0].axvline(175, color='red', ls='--', lw=1)
axs[0].axvline(215, color='red', ls='--', lw=1)
axs[0].legend(); axs[0].grid(True)

# Dispersion
axs[1].errorbar(centers, dispersions, yerr=sigma_errs,
                fmt='o', ecolor=colors[1], color=colors[1],
                capsize=3, label='Hα σ')
axs[1].set_ylim(-100,500)
axs[1].set_ylabel("σ (km/s)")
axs[1].set_title("Hα σ vs. Slit Position")
axs[1].axvline(175, color='red', ls='--', lw=1)
axs[1].axvline(215, color='red', ls='--', lw=1)
axs[1].legend(); axs[1].grid(True)

# Equivalent Width
axs[2].errorbar(centers, EWs, yerr = EW_errs,
                fmt='o', ecolor=colors[2], color=colors[2],
                capsize=3, label='Hα EW')
axs[2].set_ylabel("EW (Å)")
axs[2].set_xlabel("Slit Position (arcsec)")
axs[2].set_title("Hα EW vs. Slit Position")
axs[2].axvline(175, color='red', ls='--', lw=1)
axs[2].axvline(215, color='red', ls='--', lw=1)
axs[2].legend(); axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame({
    'center':        centers,
    'velocity':      velocities,
    'velocity_err':  v_errs,
    'dispersion':    dispersions,
    'dispersion_err': sigma_errs,
    'EW':            EWs,
    'EW_err':        EW_errs
})

# Save to CSV
df.to_csv('../halpha results/WB2_halpha_results.csv', index=False)
