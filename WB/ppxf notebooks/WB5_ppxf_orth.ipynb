# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,
)

# %%
raw = np.load("../calibrated data/WB5_data_orth.npy")       # rename your 2D array
waveem = np.load("../calibrated data/WB5_waveem_orth.npy")

window_size = 5
step        = 1
scale       = 0.4   # arcsec per pixel

pix_min, pix_max = 150, 250   
results = []
raw_roi = raw[:, pix_min:pix_max]

for start in range(0, raw_roi.shape[1] - window_size + 1, step):
    end = start + window_size
    spectrum = raw_roi[:, start:end].sum(axis=1)

    # Build DataFrame for this spectrum
    df_spec = pd.DataFrame({
        "waveem": waveem,
        "flux":   spectrum
    })

    # Process, rebin, and run pPXF
    df_cut = process_spectrum(df_spec)
    noise = make_noise(df_cut)
    df_rb, lam, flux_rb, ln_w = rebin_to_log(df_cut)
    velscale, fwhm = calculate_velscale_fwhm(ln_w, lam)
    pp, gas_templates = run_ppxf(lam, fwhm, velscale, df_rb, noise)

    # Compute global center index
    center = start + window_size//2 + pix_min
    print(f'PIXEL: {center}')

    # Store center, rebinned DataFrame, and fit result
    results.append((center, df_rb, pp))
# Out:
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       108
#  comp.  1:        -0       200
#  comp.  2:         0       200
# chi2/DOF: 0.7230; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       47.      -0   200
# Comp:  2           [NII]6583_d      0.000       60.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.14 s
# PIXEL: 152
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1447         1
#  comp.  1:         0       200
#  comp.  2:        -0       200
# chi2/DOF: 0.7236; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       51.       0   200
# Comp:  2           [NII]6583_d      0.000       65.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.30 s
# PIXEL: 153
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1796         3
#  comp.  1:        -0       200
#  comp.  2:        -0       200
# chi2/DOF: 0.7663; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       35.      -0   200
# Comp:  2           [NII]6583_d      0.000       44.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.34 s
# PIXEL: 154
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000         1
#  comp.  1:        -0       200
#  comp.  2:         0       200
# chi2/DOF: 0.6819; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       38.      -0   200
# Comp:  2           [NII]6583_d      0.000       48.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.85 s
# PIXEL: 155
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -742         1
#  comp.  1:        -0       200
#  comp.  2:         0       200
# chi2/DOF: 0.7811; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       30.      -0   200
# Comp:  2           [NII]6583_d      0.000       38.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.92 s
# PIXEL: 156
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -754         1
#  comp.  1:         0       200
#  comp.  2:        -4       182
# chi2/DOF: 0.7185; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       27.       0   200
# Comp:  2           [NII]6583_d      1.900       32.      -4   182
# -----------------------------------------------------------------
# pPXF fit done in 0.95 s
# PIXEL: 157
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -908        14
#  comp.  1:        -0       200
#  comp.  2:       -19         1
# chi2/DOF: 0.8284; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       15.      -0   200
# Comp:  2           [NII]6583_d      8.020       14.     -19     1
# -----------------------------------------------------------------
# pPXF fit done in 1.14 s
# PIXEL: 158
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1835         1
#  comp.  1:       -89       166
#  comp.  2:        17        19
# chi2/DOF: 0.9976; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       16.     -89   166
# Comp:  2           [NII]6583_d      11.25       15.      17    19
# -----------------------------------------------------------------
# pPXF fit done in 1.26 s
# PIXEL: 159
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000       321
#  comp.  1:        -0       200
#  comp.  2:      -141         1
# chi2/DOF: 0.9683; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       34.      -0   200
# Comp:  2           [NII]6583_d      0.000       31.    -141     1
# -----------------------------------------------------------------
# pPXF fit done in 1.16 s
# PIXEL: 160
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000      1000
#  comp.  1:      -797       266
#  comp.  2:        43         1
# chi2/DOF: 0.9156; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       43.    -797   266
# Comp:  2           [NII]6583_d      10.16       35.      43     1
# -----------------------------------------------------------------
# pPXF fit done in 1.33 s
# PIXEL: 161
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1914         1
#  comp.  1:         0       200
#  comp.  2:        95         1
# chi2/DOF: 1.017; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       46.       0   200
# Comp:  2           [NII]6583_d      4.272       42.      95     1
# -----------------------------------------------------------------
# pPXF fit done in 2.63 s
# PIXEL: 162
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       383
#  comp.  1:     -1084         1
#  comp.  2:       481         1
# chi2/DOF: 0.9548; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.3803       38.   -1084     1
# Comp:  2           [NII]6583_d      0.000       48.     481     1
# -----------------------------------------------------------------
# pPXF fit done in 0.97 s
# PIXEL: 163
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       395
#  comp.  1:        -5       192
#  comp.  2:       689       302
# chi2/DOF: 0.9949; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       58.      -5   192
# Comp:  2           [NII]6583_d      0.000       87.     689   302
# -----------------------------------------------------------------
# pPXF fit done in 1.03 s
# PIXEL: 164
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       472
#  comp.  1:         0       200
#  comp.  2:        35       139
# chi2/DOF: 0.8582; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       53.       0   200
# Comp:  2           [NII]6583_d      2.584       60.      35   139
# -----------------------------------------------------------------
# pPXF fit done in 1.50 s
# PIXEL: 165
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       441
#  comp.  1:       -12       192
#  comp.  2:        -4       189
# chi2/DOF: 0.9750; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 127; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       42.     -12   192
# Comp:  2           [NII]6583_d      4.176       53.      -4   189
# -----------------------------------------------------------------
# pPXF fit done in 1.62 s
# PIXEL: 166
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1494         1
#  comp.  1:        -2       198
#  comp.  2:        26       244
# chi2/DOF: 0.7905; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.1149       26.      -2   198
# Comp:  2           [NII]6583_d      7.633       36.      26   244
# -----------------------------------------------------------------
# pPXF fit done in 1.73 s
# PIXEL: 167
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1451         1
#  comp.  1:        -5        94
#  comp.  2:       172       263
# chi2/DOF: 0.7724; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.068       17.      -5    94
# Comp:  2           [NII]6583_d      12.55       30.     172   263
# -----------------------------------------------------------------
# pPXF fit done in 1.21 s
# PIXEL: 168
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1472         1
#  comp.  1:        58         1
#  comp.  2:       347       270
# chi2/DOF: 0.6202; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.752       15.      58     1
# Comp:  2           [NII]6583_d      13.19       30.     347   270
# -----------------------------------------------------------------
# pPXF fit done in 1.72 s
# PIXEL: 169
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1433         1
#  comp.  1:      -253       159
#  comp.  2:       392       289
# chi2/DOF: 0.6951; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.264       9.9    -253   159
# Comp:  2           [NII]6583_d      15.41       16.     392   289
# -----------------------------------------------------------------
# pPXF fit done in 2.52 s
# PIXEL: 170
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -564        31
#  comp.  1:       -12       192
#  comp.  2:        31       206
# chi2/DOF: 0.7282; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.479       10.     -12   192
# Comp:  2           [NII]6583_d      7.343       13.      31   206
# -----------------------------------------------------------------
# pPXF fit done in 1.14 s
# PIXEL: 171
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1348         1
#  comp.  1:      -106       248
#  comp.  2:       290       355
# chi2/DOF: 0.7505; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 226; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.777       13.    -106   248
# Comp:  2           [NII]6583_d      11.00       19.     290   355
# -----------------------------------------------------------------
# pPXF fit done in 2.48 s
# PIXEL: 172
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000         1
#  comp.  1:        -6       185
#  comp.  2:       127       236
# chi2/DOF: 0.7100; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.212       14.      -6   185
# Comp:  2           [NII]6583_d      9.923       19.     127   236
# -----------------------------------------------------------------
# pPXF fit done in 1.82 s
# PIXEL: 173
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -750         1
#  comp.  1:       -55       175
#  comp.  2:        27       208
# chi2/DOF: 0.7440; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 71; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.830       12.     -55   175
# Comp:  2           [NII]6583_d      7.756       17.      27   208
# -----------------------------------------------------------------
# pPXF fit done in 1.23 s
# PIXEL: 174
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000         1
#  comp.  1:        77         1
#  comp.  2:        30         5
# chi2/DOF: 0.7406; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.385       9.0      77     1
# Comp:  2           [NII]6583_d      1.715       11.      30     5
# -----------------------------------------------------------------
# pPXF fit done in 1.87 s
# PIXEL: 175
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -768         1
#  comp.  1:        -9       135
#  comp.  2:        37       186
# chi2/DOF: 0.7438; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.667       9.8      -9   135
# Comp:  2           [NII]6583_d      1.857       14.      37   186
# -----------------------------------------------------------------
# pPXF fit done in 0.99 s
# PIXEL: 176
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       365       126
#  comp.  1:        44         1
#  comp.  2:        40       301
# chi2/DOF: 0.7060; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.623       6.5      44     1
# Comp:  2           [NII]6583_d      0.000       14.      40   301
# -----------------------------------------------------------------
# pPXF fit done in 1.68 s
# PIXEL: 177
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1975         1
#  comp.  1:        20         1
#  comp.  2:      -241         1
# chi2/DOF: 0.6800; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 172; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.993       5.2      20     1
# Comp:  2           [NII]6583_d      1.025       6.6    -241     1
# -----------------------------------------------------------------
# pPXF fit done in 1.63 s
# PIXEL: 178
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -714         1
#  comp.  1:        55         1
#  comp.  2:      -118       195
# chi2/DOF: 0.6908; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.821       3.7      55     1
# Comp:  2           [NII]6583_d      0.000       6.5    -118   195
# -----------------------------------------------------------------
# pPXF fit done in 1.72 s
# PIXEL: 179
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       335         1
#  comp.  1:        53         1
#  comp.  2:      -174       273
# chi2/DOF: 0.7652; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 226; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.103       3.4      53     1
# Comp:  2           [NII]6583_d      3.102       6.7    -174   273
# -----------------------------------------------------------------
# pPXF fit done in 2.45 s
# PIXEL: 180
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000       411
#  comp.  1:       404       311
#  comp.  2:     -1713      1000
# chi2/DOF: 0.9083; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.415       13.     404   311
# Comp:  2           [NII]6583_d      9.362       24.   -1713  1000
# -----------------------------------------------------------------
# pPXF fit done in 1.44 s
# PIXEL: 181
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000         1
#  comp.  1:       322       511
#  comp.  2:        -6       243
# chi2/DOF: 0.9399; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.295       24.     322   511
# Comp:  2           [NII]6583_d      0.000       22.      -6   243
# -----------------------------------------------------------------
# pPXF fit done in 0.97 s
# PIXEL: 182
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      2000         1
#  comp.  1:       433       583
#  comp.  2:        -4       199
# chi2/DOF: 0.9388; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.345       27.     433   583
# Comp:  2           [NII]6583_d      0.000       21.      -4   199
# -----------------------------------------------------------------
# pPXF fit done in 1.09 s
# PIXEL: 183
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1000       192
#  comp.  1:      1462      1000
#  comp.  2:      -210       549
# chi2/DOF: 0.9433; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       36.    1462  1000
# Comp:  2           [NII]6583_d      8.999       33.    -210   549
# -----------------------------------------------------------------
# pPXF fit done in 1.10 s
# PIXEL: 184
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       966         1
#  comp.  1:       321         1
#  comp.  2:       -18        71
# chi2/DOF: 0.8990; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 73; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       7.0     321     1
# Comp:  2           [NII]6583_d      1.767       9.5     -18    71
# -----------------------------------------------------------------
# pPXF fit done in 1.37 s
# PIXEL: 185
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1107       456
#  comp.  1:       112         1
#  comp.  2:      -107         1
# chi2/DOF: 0.6744; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.043       3.5     112     1
# Comp:  2           [NII]6583_d     0.7613       4.4    -107     1
# -----------------------------------------------------------------
# pPXF fit done in 2.92 s
# PIXEL: 186
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -328      1000
#  comp.  1:       105         1
#  comp.  2:      -109         1
# chi2/DOF: 0.4852; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 139; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.410       2.5     105     1
# Comp:  2           [NII]6583_d     0.4055       3.2    -109     1
# -----------------------------------------------------------------
# pPXF fit done in 1.70 s
# PIXEL: 187
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       110      1000
#  comp.  1:        59         1
#  comp.  2:       -34       185
# chi2/DOF: 0.4258; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 105; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.212       2.5      59     1
# Comp:  2           [NII]6583_d      0.000       4.3     -34   185
# -----------------------------------------------------------------
# pPXF fit done in 1.64 s
# PIXEL: 188
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1811       504
#  comp.  1:        42        75
#  comp.  2:        -0       200
# chi2/DOF: 0.3394; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.040       2.7      42    75
# Comp:  2           [NII]6583_d      0.000       4.4      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 3.36 s
# PIXEL: 189
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1735       701
#  comp.  1:        23        57
#  comp.  2:      -289       192
# chi2/DOF: 0.2292; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 226; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.283       2.1      23    57
# Comp:  2           [NII]6583_d      1.243       3.5    -289   192
# -----------------------------------------------------------------
# pPXF fit done in 3.36 s
# PIXEL: 190
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1713       990
#  comp.  1:        31        66
#  comp.  2:      -232       163
# chi2/DOF: 0.2223; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.964       2.1      31    66
# Comp:  2           [NII]6583_d      1.000       3.2    -232   163
# -----------------------------------------------------------------
# pPXF fit done in 1.84 s
# PIXEL: 191
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       680
#  comp.  1:        33        47
#  comp.  2:      -260       345
# chi2/DOF: 0.2138; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 16; Func calls: 276; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.228       1.8      33    47
# Comp:  2           [NII]6583_d      1.765       3.9    -260   345
# -----------------------------------------------------------------
# pPXF fit done in 2.80 s
# PIXEL: 192
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       482        82
#  comp.  1:        47        54
#  comp.  2:      -125       379
# chi2/DOF: 0.6897; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.421       4.2      47    54
# Comp:  2           [NII]6583_d      4.371       9.2    -125   379
# -----------------------------------------------------------------
# pPXF fit done in 1.44 s
# PIXEL: 193
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       676       531
#  comp.  1:        40        51
#  comp.  2:       -24       343
# chi2/DOF: 0.7200; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.67       4.0      40    51
# Comp:  2           [NII]6583_d      4.724       8.4     -24   343
# -----------------------------------------------------------------
# pPXF fit done in 0.69 s
# PIXEL: 194
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1919       600
#  comp.  1:        44        58
#  comp.  2:        -2       235
# chi2/DOF: 0.7768; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      13.70       4.5      44    58
# Comp:  2           [NII]6583_d      4.291       7.9      -2   235
# -----------------------------------------------------------------
# pPXF fit done in 1.05 s
# PIXEL: 195
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       608       392
#  comp.  1:        44        60
#  comp.  2:       -13       216
# chi2/DOF: 0.8000; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      16.17       4.5      44    60
# Comp:  2           [NII]6583_d      5.504       7.8     -13   216
# -----------------------------------------------------------------
# pPXF fit done in 0.82 s
# PIXEL: 196
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       385       178
#  comp.  1:        39        58
#  comp.  2:       -27       210
# chi2/DOF: 0.8302; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      17.78       5.3      39    58
# Comp:  2           [NII]6583_d      5.873       9.0     -27   210
# -----------------------------------------------------------------
# pPXF fit done in 1.10 s
# PIXEL: 197
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       377       203
#  comp.  1:        34        60
#  comp.  2:       -57       287
# chi2/DOF: 0.8814; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      17.22       4.7      34    60
# Comp:  2           [NII]6583_d      6.105       9.1     -57   287
# -----------------------------------------------------------------
# pPXF fit done in 1.22 s
# PIXEL: 198
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       513         1
#  comp.  1:        35        58
#  comp.  2:      -101       290
# chi2/DOF: 0.8747; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      14.48       4.7      35    58
# Comp:  2           [NII]6583_d      5.727       9.0    -101   290
# -----------------------------------------------------------------
# pPXF fit done in 1.06 s
# PIXEL: 199
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       124       712
#  comp.  1:        25        55
#  comp.  2:       -97       342
# chi2/DOF: 0.8888; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.93       4.1      25    55
# Comp:  2           [NII]6583_d      5.156       8.5     -97   342
# -----------------------------------------------------------------
# pPXF fit done in 0.65 s
# PIXEL: 200
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -133       595
#  comp.  1:        14        31
#  comp.  2:     -1188      1000
# chi2/DOF: 0.8333; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 105; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.598       4.0      14    31
# Comp:  2           [NII]6583_d      10.79       12.   -1188  1000
# -----------------------------------------------------------------
# pPXF fit done in 1.15 s
# PIXEL: 201
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -136       676
#  comp.  1:         2        57
#  comp.  2:     -1526      1000
# chi2/DOF: 0.5381; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.059       1.9       2    57
# Comp:  2           [NII]6583_d      5.696       5.8   -1526  1000
# -----------------------------------------------------------------
# pPXF fit done in 1.64 s
# PIXEL: 202
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -20       385
#  comp.  1:       -17        50
#  comp.  2:      -188         1
# chi2/DOF: 0.3133; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 175; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.113       1.3     -17    50
# Comp:  2           [NII]6583_d     0.9162       1.6    -188     1
# -----------------------------------------------------------------
# pPXF fit done in 2.09 s
# PIXEL: 203
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:         6       435
#  comp.  1:       -24        38
#  comp.  2:      -160         1
# chi2/DOF: 0.3678; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 177; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.893       1.3     -24    38
# Comp:  2           [NII]6583_d     0.9200       1.6    -160     1
# -----------------------------------------------------------------
# pPXF fit done in 2.07 s
# PIXEL: 204
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        30       444
#  comp.  1:       -24        37
#  comp.  2:      -147         1
# chi2/DOF: 0.4030; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1402         1
#  comp.  1:        87         1
#  comp.  2:      -147         1
# chi2/DOF: 0.7723; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.25       8.8      87     1
# Comp:  2           [NII]6583_d      4.089       11.    -147     1
# -----------------------------------------------------------------
# pPXF fit done in 1.21 s
# PIXEL: 230
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1405         1
#  comp.  1:        45         1
#  comp.  2:        -1       194
# chi2/DOF: 0.7367; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.90       13.      45     1
# Comp:  2           [NII]6583_d     0.5295       23.      -1   194
# -----------------------------------------------------------------
# pPXF fit done in 1.42 s
# PIXEL: 231
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1829       723
#  comp.  1:        11        42
#  comp.  2:       -65         1
# chi2/DOF: 0.8355; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      15.03       20.      11    42
# Comp:  2           [NII]6583_d      7.361       24.     -65     1
# -----------------------------------------------------------------
# pPXF fit done in 1.13 s
# PIXEL: 232
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1516        28
#  comp.  1:      -318        43
#  comp.  2:         0       200
# chi2/DOF: 0.8424; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       34.    -318    43
# Comp:  2           [NII]6583_d      0.000       57.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 2.20 s
# PIXEL: 233
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1942         1
#  comp.  1:        61         1
#  comp.  2:        -0       200
# chi2/DOF: 0.8300; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.235       30.      61     1
# Comp:  2           [NII]6583_d      0.000       53.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.03 s
# PIXEL: 234
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -337         1
#  comp.  1:         0       200
#  comp.  2:        -0       200
# chi2/DOF: 0.6630; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       75.       0   200
# Comp:  2           [NII]6583_d      0.000       95.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.12 s
# PIXEL: 235
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1154         1
#  comp.  1:        -0       200
#  comp.  2:         0       200
# chi2/DOF: 0.7969; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 210; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.3e+02      -0   200
# Comp:  2           [NII]6583_d      0.000   1.7e+02       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.95 s
# PIXEL: 236
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1969         1
#  comp.  1:         0       200
#  comp.  2:         0       200
# chi2/DOF: 0.7110; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.5e+02       0   200
# Comp:  2           [NII]6583_d      0.000   1.9e+02       0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.78 s
# PIXEL: 237
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1956         1
#  comp.  1:        -0       200
#  comp.  2:         0       200
# chi2/DOF: 0.7654; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.4e+02      -0   200
# Comp:  2           [NII]6583_d      0.000   1.8e+02       0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.66 s
# PIXEL: 238
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1951         1
#  comp.  1:         0       200
#  comp.  2:         0       200
# chi2/DOF: 0.8307; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.1e+02       0   200
# Comp:  2           [NII]6583_d      0.000   1.4e+02       0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.69 s
# PIXEL: 239
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1945         1
#  comp.  1:         0       200
#  comp.  2:         0       200
# chi2/DOF: 0.6032; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 94; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.1e+02       0   200
# Comp:  2           [NII]6583_d      0.000   1.3e+02       0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.79 s
# PIXEL: 240
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1901         1
#  comp.  1:        22       311
#  comp.  2:      -123       474
# chi2/DOF: 0.7189; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 211; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       34.      22   311
# Comp:  2           [NII]6583_d      8.541       51.    -123   474
# -----------------------------------------------------------------
# pPXF fit done in 2.46 s
# PIXEL: 241
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -936       169
#  comp.  1:      -206      1000
#  comp.  2:        17       240
# chi2/DOF: 0.7234; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      30.67       42.    -206  1000
# Comp:  2           [NII]6583_d      0.000       28.      17   240
# -----------------------------------------------------------------
# pPXF fit done in 1.32 s
# PIXEL: 242
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1228         1
#  comp.  1:       -66      1000
#  comp.  2:       -14       212
# chi2/DOF: 0.7625; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      30.26       40.     -66  1000
# Comp:  2           [NII]6583_d      0.000       25.     -14   212
# -----------------------------------------------------------------
# pPXF fit done in 1.37 s
# PIXEL: 243
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -766       531
#  comp.  1:       106         1
#  comp.  2:      -245         1
# chi2/DOF: 0.8606; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.608       28.     106     1
# Comp:  2           [NII]6583_d      7.187       36.    -245     1
# -----------------------------------------------------------------
# pPXF fit done in 1.25 s
# PIXEL: 244
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000      1000
#  comp.  1:        -0       200
#  comp.  2:        -0       200
# chi2/DOF: 0.7339; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.2e+02      -0   200
# Comp:  2           [NII]6583_d      0.000   1.5e+02      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.84 s
# PIXEL: 245
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       741
#  comp.  1:         0       200
#  comp.  2:        -0       200
# chi2/DOF: 1.067; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.6e+02       0   200
# Comp:  2           [NII]6583_d      0.000   2.1e+02      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.02 s
# PIXEL: 246
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000         1
#  comp.  1:      -656       170
#  comp.  2:        -0       200
# chi2/DOF: 1.260; DOF: 1595; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   3.4e+02    -656   170
# Comp:  2           [NII]6583_d      0.000   4.6e+02      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.65 s
# PIXEL: 247

# %%
# raw.shape == (n_wave, n_spatial)
spatial_flux = raw.sum(axis=0)       # total flux in each slit column
slit_pixels  = np.arange(raw.shape[1])

# Only look between 150 and 250
search_range = slice(170, 251)
peak_rel = np.argmax(spatial_flux[search_range])
peak = slit_pixels[search_range][peak_rel]

print(f"Peak flux at {peak} px")

plt.figure(figsize=(8, 4))
plt.axvline(peak, color='green', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
plt.axvline(175, color='red', linestyle='--', linewidth=1)
plt.axvline(215, color='red', linestyle='--', linewidth=1)
plt.ylim(-20000,60000)
plt.scatter(slit_pixels, spatial_flux, s=10)
plt.xlabel("Slit Pixel")
plt.ylabel("Integrated Flux")
plt.title("Flux vs. Slit Position")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Peak flux at 203 px

# %%
for center, df_rb, pp in results[25:100]:
    # Ensure the function can access 'lam'
    lam_array = df_rb['lam'].values
    plot_ppxf.__globals__['lam'] = lam_array

    print(f"Window centre: {center}")
    plot_ppxf(df_rb, pp)

    # Extract and print the Hα sigma (km/s)
    sigma = pp.sol[1][1]
    print(f"σ (km/s): {sigma:.2f}\n")
# Out:
# Window centre: 177
# σ (km/s): 1.01
#
# Window centre: 178
# σ (km/s): 1.01
#
# Window centre: 179
# σ (km/s): 1.01
#
# Window centre: 180
# σ (km/s): 1.01
#
# Window centre: 181
# σ (km/s): 310.92
#
# Window centre: 182
# σ (km/s): 510.70
#
# Window centre: 183
# σ (km/s): 582.96
#
# Window centre: 184
# σ (km/s): 1000.00
#
# Window centre: 185
# σ (km/s): 1.01
#
# Window centre: 186
# σ (km/s): 1.01
#
# Window centre: 187
# σ (km/s): 1.01
#
# Window centre: 188
# σ (km/s): 1.01
#
# Window centre: 189
# σ (km/s): 74.59
#
# Window centre: 190
# σ (km/s): 56.63
#
# Window centre: 191
# σ (km/s): 65.96
#
# Window centre: 192
# σ (km/s): 46.60
#
# Window centre: 193
# σ (km/s): 53.63
#
# Window centre: 194
# σ (km/s): 51.48
#
# Window centre: 195
# σ (km/s): 58.18
#
# Window centre: 196
# σ (km/s): 60.27
#
# Window centre: 197
# σ (km/s): 58.21
#
# Window centre: 198
# σ (km/s): 59.68
#
# Window centre: 199
# σ (km/s): 58.12
#
# Window centre: 200
# σ (km/s): 55.09
#
# Window centre: 201
# σ (km/s): 31.35
#
# Window centre: 202
# σ (km/s): 57.42
#
# Window centre: 203
# σ (km/s): 50.33
#
# Window centre: 204
# σ (km/s): 37.61
#
# Window centre: 205
# σ (km/s): 36.83
#
# Window centre: 206
# σ (km/s): 1.01
#
# Window centre: 207
# σ (km/s): 1.01
#
# Window centre: 208
# σ (km/s): 20.27
#
# Window centre: 209
# σ (km/s): 18.18
#
# Window centre: 210
# σ (km/s): 30.91
#
# Window centre: 211
# σ (km/s): 32.55
#
# Window centre: 212
# σ (km/s): 52.13
#
# Window centre: 213
# σ (km/s): 40.35
#
# Window centre: 214
# σ (km/s): 43.67
#
# Window centre: 215
# σ (km/s): 42.99
#
# Window centre: 216
# σ (km/s): 39.74
#
# Window centre: 217
# σ (km/s): 10.86
#
# Window centre: 218
# σ (km/s): 38.02
#
# Window centre: 219
# σ (km/s): 14.75
#
# Window centre: 220
# σ (km/s): 44.35
#
# Window centre: 221
# σ (km/s): 31.07
#
# Window centre: 222
# σ (km/s): 1.01
#
# Window centre: 223
# σ (km/s): 44.62
#
# Window centre: 224
# σ (km/s): 9.42
#
# Window centre: 225
# σ (km/s): 91.22
#
# Window centre: 226
# σ (km/s): 129.91
#
# Window centre: 227
# σ (km/s): 68.78
#
# Window centre: 228
# σ (km/s): 1.01
#
# Window centre: 229
# σ (km/s): 51.73
#
# Window centre: 230
# σ (km/s): 1.01
#
# Window centre: 231
# σ (km/s): 1.01
#
# Window centre: 232
# σ (km/s): 41.97
#
# Window centre: 233
# σ (km/s): 42.82
#
# Window centre: 234
# σ (km/s): 1.01
#
# Window centre: 235
# σ (km/s): 200.00
#
# Window centre: 236
# σ (km/s): 200.00
#
# Window centre: 237
# σ (km/s): 200.00
#
# Window centre: 238
# σ (km/s): 200.00
#
# Window centre: 239
# σ (km/s): 200.00
#
# Window centre: 240
# σ (km/s): 200.00
#
# Window centre: 241
# σ (km/s): 310.95
#
# Window centre: 242
# σ (km/s): 1000.00
#
# Window centre: 243
# σ (km/s): 1000.00
#
# Window centre: 244
# σ (km/s): 1.01
#
# Window centre: 245
# σ (km/s): 200.00
#
# Window centre: 246
# σ (km/s): 200.00
#
# Window centre: 247
# σ (km/s): 170.07

# %%
centers     = []
velocities  = []; v_errs     = []
dispersions = []; sigma_errs = []
EWs         = []; EW_errs    = []

for center, _, pp in results:
    # --- extract Hα kinematics from the list ---
    sol_gas    = pp.sol[1]
    err_gas    = pp.error[1]
    v_ha, sigma_ha       = sol_gas
    #sigma = np.sqrt(sigma_inst**2 + sigma_ha**2)

    v_ha_err, sigma_ha_err = err_gas

    # find Hα in gas_names (should be idx 0 here)
    idx = np.where(pp.gas_names == "Halpha")[0][0]

    # compute flux, continuum & EW as before
    flux_ha   = pp.gas_flux[idx]
    continuum = pp.bestfit - pp.gas_bestfit
    peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
    cont0     = continuum[peak_i]
    cont_err  = pp.noise[peak_i]
    flux_err  = pp.gas_flux_error[idx]

    EW        = flux_ha / cont0
    EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

    # store
    centers.append(center)
    velocities.append(v_ha)
    v_errs.append(v_ha_err)
    dispersions.append(sigma_ha)
    sigma_errs.append(sigma_ha_err)
    EWs.append(EW)
    EW_errs.append(EW_err)
# Out:
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_36093/3518839896.py:27: RuntimeWarning: divide by zero encountered in scalar divide
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_36093/3518839896.py:27: RuntimeWarning: invalid value encountered in scalar multiply
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

# %%
fig, axs = plt.subplots(3,1,figsize=(10,9),sharex=True)

colors = ['#1f77b4', '#2ca02c', '#d62728']  # blue, green, red


# Velocity
axs[0].errorbar(centers, velocities, yerr=v_errs,
                fmt='o', ecolor=colors[0], color=colors[0],
                capsize=3, label='Hα Velocity')
axs[0].set_ylabel("Velocity (km/s)")
axs[0].set_title("Hα Velocity vs. Slit Position")
axs[0].axvline(175, color='red', ls='--', lw=1)
axs[0].axvline(215, color='red', ls='--', lw=1)
axs[0].legend(); axs[0].grid(True)

# Dispersion
axs[1].errorbar(centers, dispersions, yerr=sigma_errs,
                fmt='o', ecolor=colors[1], color=colors[1],
                capsize=3, label='Hα σ')
axs[1].set_ylim(-100,500)
axs[1].set_ylabel("σ (km/s)")
axs[1].set_title("Hα σ vs. Slit Position")
axs[1].axvline(175, color='red', ls='--', lw=1)
axs[1].axvline(215, color='red', ls='--', lw=1)
axs[1].legend(); axs[1].grid(True)

# Equivalent Width
axs[2].errorbar(centers, EWs, yerr = EW_errs,
                fmt='o', ecolor=colors[2], color=colors[2],
                capsize=3, label='Hα EW')
axs[2].set_ylabel("EW (Å)")
axs[2].set_xlabel("Slit Position (arcsec)")
axs[2].set_title("Hα EW vs. Slit Position")
axs[2].axvline(175, color='red', ls='--', lw=1)
axs[2].axvline(215, color='red', ls='--', lw=1)
axs[2].legend(); axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame({
    'center':        centers,
    'velocity':      velocities,
    'velocity_err':  v_errs,
    'dispersion':    dispersions,
    'dispersion_err': sigma_errs,
    'EW':            EWs,
    'EW_err':        EW_errs
})

# Save to CSV
df.to_csv('../halpha results/WB5_orth_halpha_results.csv', index=False)
