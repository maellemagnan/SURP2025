# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,
)

# %%
raw = np.load("../calibrated data/SB2_data.npy")       # rename your 2D array
waveem = np.load("../calibrated data/SB2_waveem.npy")

window_size = 5
step        = 1
scale       = 0.4   # arcsec per pixel

pix_min, pix_max = 150, 250   
results = []
# slice out only those columns, then slide your window over that
raw_roi = raw[:, pix_min:pix_max]
for start in range(0, raw_roi.shape[1] - window_size + 1, step):
    end      = start + window_size
    spectrum = raw_roi[:, start:end].mean(axis=1)

    df_spec = pd.DataFrame({
        "waveem": waveem,
        "flux":   spectrum
    })

    # now run your pipeline on df_spec
    df_cut                      = process_spectrum(df_spec)
    noise                       = make_noise(df_cut)
    df_rb, lam, flux_rb, ln_w   = rebin_to_log(df_cut)
    velscale, fwhm              = calculate_velscale_fwhm(ln_w, lam)
    pp, gas_templates           = run_ppxf(lam, fwhm, velscale, df_rb, noise)
    

    center = (start + window_size//2) 
    results.append((center, pp))
# Out:
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 26
#      24 df_rb, lam, flux_rb, ln_w   = rebin_to_log(df_cut)
#      25 velscale, fwhm              = calculate_velscale_fwhm(ln_w, lam)
# ---> 26 pp, gas_templates           = run_ppxf(lam, fwhm, velscale, df_rb, noise)
#      29 center = (start + window_size//2)
#      30 results.append((center, pp))
#
# File ~/Documents/SURP/Notebooks/SB/ppxf notebooks/ppxf_functions.py:114, in run_ppxf(lam, fwhm, velscale, data, noise)
#     110 b_ineq = [5]
#     111 constr_kinem = {"A_ineq": A_ineq, "b_ineq": b_ineq}
# --> 114 pp = ppxf(templates, galaxy, noise, velscale, start, plot=False,
#     115         moments=moments, degree=degree, mdegree=mdegree,
#     116         lam=lam, component=component,
#     117         gas_component=component > 0, gas_names=gas_names,
#     118         lam_temp=sps.lam_temp, constr_kinem = constr_kinem)
#     119 print(f"pPXF fit done in {clock()-t:.2f} s")
#     121 return pp, gas_templates
#
# File ~/anaconda3/lib/python3.11/site-packages/ppxf/ppxf.py:1917, in ppxf.__init__(self, templates, galaxy, noise, velscale, start, bias, bounds, clean, component, constr_templ, constr_kinem, degree, dust, fit, fixed, fraction, ftol, gas_component, gas_names, gas_reddening, gas_reddening_func, global_search, goodpixels, lam, lam_temp, linear, linear_method, mask, method, mdegree, moments, phot, plot, quiet, reddening, reddening_func, reg_dim, reg_ord, reg_step, regul, sigma_diff, sky, templates_rfft, tied, trig, velscale_ratio, vsyst, x0)
#    1915     self.njev = 0     # Jacobian is not evaluated
#    1916 else:
# -> 1917     params, perror = self.nonlinear_fit(start1, bounds, fixed, tied, clean)
#    1919 self.bias = 0   # Evaluate residuals without bias
#    1920 err = self.linear_fit(params)
#
# File ~/anaconda3/lib/python3.11/site-packages/ppxf/ppxf.py:2297, in ppxf.nonlinear_fit(self, start0, bounds0, fixed0, tied0, clean)
#    2295 self.clean = False  # No cleaning during chi2 optimization
#    2296 if self.method == 'capfit':
# -> 2297     res = capfit(
#    2298         self.linear_fit, start, ftol=self.ftol, bounds=bounds.T,
#    2299         abs_step=step, x_scale='jac', tied=tied, fixed=fixed,
#    2300         A_ineq=self.A_ineq_kinem, b_ineq=self.b_ineq_kinem,
#    2301         A_eq=self.A_eq_kinem, b_eq=self.b_eq_kinem)
#    2302     perror = res.x_err
#    2303 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/capfit/capfit.py:744, in capfit.__init__(self, func, p0, A_eq, A_ineq, abs_step, b_eq, b_ineq, bounds, diff_step, fixed, ftol, max_nfev, monitor, rcond, tied, verbose, x_scale, xtol, args, kwargs)
#     740     assert np.all(np.isfinite(resid)), \
#     741         "The fitting function returned infinite residuals"
#     742     return resid
# --> 744 p1, p1_err = self.optimize(call, p0[free], A_eq, b_eq, A_ineq, b_ineq, bounds[:, free])
#     746 self.x = tie(p1)   # Return both free and tied/fixed variables
#     747 self.x_err = np.zeros_like(self.x)
#
# File ~/anaconda3/lib/python3.11/site-packages/capfit/capfit.py:824, in capfit.optimize(self, call, p1, A_eq, b_eq, A_ineq, b_ineq, bounds)
#     822         if (self.monitor is not None) and (self.njev % self.monitor["num"] == 0):
#     823             self.monitor["fun"](p2, self.njev, chi2(f2))
# --> 824         J1 = self.fdjac(call, p2, f2, bounds)
#     825         p1, f1 = p2, f2
#     827 self.chi2 = chi2(f1)
#
# File ~/anaconda3/lib/python3.11/site-packages/capfit/capfit.py:867, in capfit.fdjac(self, call, pars, f, bounds)
#     865     pars1 = pars.copy()
#     866     pars1[j] += hj
# --> 867     f1 = call(pars1)
#     868     jac[:, j] = (f1 - f)/hj
#     870 return jac
#
# File ~/anaconda3/lib/python3.11/site-packages/capfit/capfit.py:739, in capfit.__init__.<locals>.call(pfree)
#     737 self.nfev += 1
#     738 p = tie(pfree)
# --> 739 resid = func(p, *args, **kwargs)
#     740 assert np.all(np.isfinite(resid)), \
#     741     "The fitting function returned infinite residuals"
#     742 return resid
#
# File ~/anaconda3/lib/python3.11/site-packages/ppxf/ppxf.py:2365, in ppxf.linear_fit(self, pars)
#    2363 for j, template_rfft in enumerate(self.templates_rfft.T):  # loop over column templates
#    2364     for k in range(nspec):
# -> 2365         tt = np.fft.irfft(template_rfft*lvd_rfft[:, self.component[j], k], self.npad)
#    2366         tmp[k, :] = rebin(tt[:self.npix*self.velscale_ratio], self.velscale_ratio)
#    2367     c[: nrows_spec, npoly + j] = tmp.ravel()
#
# File <__array_function__ internals>:200, in irfft(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/fft/_pocketfft.py:513, in irfft(a, n, axis, norm)
#     511     n = (a.shape[axis] - 1) * 2
#     512 inv_norm = _get_backward_norm(n, norm)
# --> 513 output = _raw_fft(a, n, axis, True, False, inv_norm)
#     514 return output
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/fft/_pocketfft.py:65, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      63 index[axis] = slice(0, s[axis])
#      64 s[axis] = n
# ---> 65 z = zeros(s, a.dtype.char)
#      66 z[tuple(index)] = a
#      67 a = z
#
# KeyboardInterrupt:

# %%
# raw.shape == (n_wave, n_spatial)
spatial_flux = raw.sum(axis=0)       # total flux in each slit column
slit_pixels  = np.arange(raw.shape[1])

peak = slit_pixels[np.argmax(spatial_flux)]
print(f"Peak flux at {peak} px")

plt.figure(figsize=(8,4))

# to mark it:
plt.axvline(peak, color='green', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
plt.axvline(175, color='red', linestyle='--', linewidth=1)
plt.axvline(215, color='red', linestyle='--', linewidth=1)
plt.scatter(slit_pixels, spatial_flux, s=10)
plt.xlabel("Slit Pixel")
plt.ylabel("Integrated Flux")
plt.title("Flux vs. Slit Position")
plt.grid(True, )
plt.show()

# %%
centers = []
velocities, v_errs = [], []
dispersions, sigma_errs = [], []
EWs = []
EW_errs = []

for center, pp in results:
    # 1) velocity & sigma of Hα (component 1) + their errors
    v = pp.sol[1][0]
    v_err = pp.error[1][0]
    sigma = pp.sol[1][1]
    sigma_err = pp.error[1][1]

    # 2) find the index of "Halpha" in the NumPy array gas_names
    idx_arr = np.where(pp.gas_names == "Halpha")[0]
    if idx_arr.size == 0:
        # fallback or skip if not found
        continue
    idx = idx_arr[0]

    # 3) integrated Hα flux
    flux_ha = pp.gas_flux[idx]

    # 4) continuum at the Hα peak
    continuum = pp.bestfit - pp.gas_bestfit
    peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
    cont0     = continuum[peak_i]

    # 5) equivalent width
    EW = flux_ha / cont0
    cont_err = pp.noise[peak_i]
    EW_err = EW * (cont_err/cont0)


    # store everything
    EW_errs.append(EW_err)
    centers.append(center + 150)
    velocities.append(v)
    v_errs.append(v_err)
    dispersions.append(sigma)
    sigma_errs.append(sigma_err)
    EWs.append(EW)

# %%
fig, axs = plt.subplots(3,1,figsize=(10,9),sharex=True)

colors = ['#1f77b4', '#2ca02c', '#d62728']  # blue, green, red


# Velocity
axs[0].errorbar(centers, velocities, yerr=v_errs,
                fmt='o', ecolor=colors[0], color=colors[0],
                capsize=3, label='Hα Velocity')
axs[0].set_ylabel("Velocity (km/s)")
axs[0].set_title("Hα Velocity vs. Slit Position")
axs[0].axvline(175, color='red', ls='--', lw=1)
axs[0].axvline(215, color='red', ls='--', lw=1)
axs[0].legend(); axs[0].grid(True)

# Dispersion
axs[1].errorbar(centers, dispersions, yerr=sigma_errs,
                fmt='o', ecolor=colors[1], color=colors[1],
                capsize=3, label='Hα σ')
axs[1].set_ylim(-100,500)
axs[1].set_ylabel("σ (km/s)")
axs[1].set_title("Hα σ vs. Slit Position")
axs[1].axvline(175, color='red', ls='--', lw=1)
axs[1].axvline(215, color='red', ls='--', lw=1)
axs[1].legend(); axs[1].grid(True)

# Equivalent Width
axs[2].errorbar(centers, EWs, yerr = EW_errs,
                fmt='o', ecolor=colors[2], color=colors[2],
                capsize=3, label='Hα EW')
axs[2].set_ylabel("EW (Å)")
axs[2].set_xlabel("Slit Position (arcsec)")
axs[2].set_title("Hα EW vs. Slit Position")
axs[2].axvline(175, color='red', ls='--', lw=1)
axs[2].axvline(215, color='red', ls='--', lw=1)
axs[2].legend(); axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame({
    'center':        centers,
    'velocity':      velocities,
    'velocity_err':  v_errs,
    'dispersion':    dispersions,
    'dispersion_err': sigma_errs,
    'EW':            EWs,
    'EW_err':        EW_errs
})

# Save to CSV
df.to_csv('../halpha results/SB2_halpha_results.csv', index=False)
