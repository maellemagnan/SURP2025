# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,)

# %%
raw = np.load("../calibrated data/SB6_data_orth.npy")
waveem = np.load("../calibrated data/SB6_waveem_orth.npy")

window_size = 5
step        = 1
scale       = 0.4   # arcsec per pixel

pix_min, pix_max = 150, 250   
results = []
raw_roi = raw[:, pix_min:pix_max]

for start in range(0, raw_roi.shape[1] - window_size + 1, step):
    end = start + window_size
    spectrum = raw_roi[:, start:end].sum(axis=1)

    # Build DataFrame for this spectrum
    df_spec = pd.DataFrame({
        "waveem": waveem,
        "flux":   spectrum
    })

    # Process, rebin, and run pPXF
    df_cut = process_spectrum(df_spec)
    noise = make_noise(df_cut)
    df_rb, lam, flux_rb, ln_w = rebin_to_log(df_cut)
    velscale, fwhm = calculate_velscale_fwhm(ln_w, lam)
    pp, gas_templates = run_ppxf(lam, fwhm, velscale, df_rb, noise)

    # Compute global center index
    center = start + window_size//2 + pix_min
    print(f'PIXEL: {center}')

    # Store center, rebinned DataFrame, and fit result
    results.append((center, df_rb, pp))
# Out:
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1037        56
#  comp.  1:      -287       127
#  comp.  2:        42       143
# chi2/DOF: 0.7271; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       6.4    -287   127
# Comp:  2           [NII]6583_d   0.005668       8.3      42   143
# -----------------------------------------------------------------
# pPXF fit done in 1.23 s
# PIXEL: 152
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       122      1000
#  comp.  1:        26        71
#  comp.  2:        -0       162
# chi2/DOF: 0.7343; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 54; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.392       5.4      26    71
# Comp:  2           [NII]6583_d      0.000       8.2      -0   162
# -----------------------------------------------------------------
# pPXF fit done in 0.64 s
# PIXEL: 153
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1099         1
#  comp.  1:       -11        52
#  comp.  2:        -4       194
# chi2/DOF: 0.7835; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.817       5.4     -11    52
# Comp:  2           [NII]6583_d      0.000       8.9      -4   194
# -----------------------------------------------------------------
# pPXF fit done in 1.08 s
# PIXEL: 154
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1085         1
#  comp.  1:       -27         1
#  comp.  2:         0       200
# chi2/DOF: 0.8141; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.856       3.4     -27     1
# Comp:  2           [NII]6583_d      0.000       6.0       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.31 s
# PIXEL: 155
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1043        88
#  comp.  1:        -3         1
#  comp.  2:        -0       200
# chi2/DOF: 0.7571; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 174; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.526       2.5      -3     1
# Comp:  2           [NII]6583_d      0.000       4.4      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.57 s
# PIXEL: 156
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1017       103
#  comp.  1:         6        14
#  comp.  2:        -0       200
# chi2/DOF: 0.7101; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.456       2.5       6    14
# Comp:  2           [NII]6583_d      0.000       4.4      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.42 s
# PIXEL: 157
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -992       147
#  comp.  1:        -3         1
#  comp.  2:         0       200
# chi2/DOF: 0.7169; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.370       2.2      -3     1
# Comp:  2           [NII]6583_d      0.000       3.8       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.35 s
# PIXEL: 158
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -783       459
#  comp.  1:       -42        59
#  comp.  2:       -57         1
# chi2/DOF: 0.7716; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.639       1.4     -42    59
# Comp:  2           [NII]6583_d     0.8842       1.6     -57     1
# -----------------------------------------------------------------
# pPXF fit done in 1.14 s
# PIXEL: 159
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -720         1
#  comp.  1:       -23       183
#  comp.  2:       -32         1
# chi2/DOF: 0.7324; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.066       1.6     -23   183
# Comp:  2           [NII]6583_d      1.662       1.5     -32     1
# -----------------------------------------------------------------
# pPXF fit done in 0.82 s
# PIXEL: 160
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -251         1
#  comp.  1:      -112        69
#  comp.  2:         0       200
# chi2/DOF: 0.7205; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.600       1.4    -112    69
# Comp:  2           [NII]6583_d      0.000       2.3       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.08 s
# PIXEL: 161
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -289         1
#  comp.  1:       -99       259
#  comp.  2:        -6         1
# chi2/DOF: 0.7328; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 208; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.831       1.9     -99   259
# Comp:  2           [NII]6583_d     0.4814       1.5      -6     1
# -----------------------------------------------------------------
# pPXF fit done in 1.69 s
# PIXEL: 162
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        26      1000
#  comp.  1:       128       201
#  comp.  2:        60         1
# chi2/DOF: 0.7320; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.185       1.7     128   201
# Comp:  2           [NII]6583_d     0.7140       1.5      60     1
# -----------------------------------------------------------------
# pPXF fit done in 0.80 s
# PIXEL: 163
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       273      1000
#  comp.  1:        75        12
#  comp.  2:      -123       199
# chi2/DOF: 0.7385; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 105; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.355       1.1      75    12
# Comp:  2           [NII]6583_d      1.121       2.0    -123   199
# -----------------------------------------------------------------
# pPXF fit done in 0.87 s
# PIXEL: 164
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       415      1000
#  comp.  1:        94         1
#  comp.  2:      -194       153
# chi2/DOF: 0.7416; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.055      0.99      94     1
# Comp:  2           [NII]6583_d     0.9396       1.6    -194   153
# -----------------------------------------------------------------
# pPXF fit done in 0.86 s
# PIXEL: 165
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -706       311
#  comp.  1:        93         1
#  comp.  2:        76         1
# chi2/DOF: 0.7470; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.9658      0.84      93     1
# Comp:  2           [NII]6583_d     0.8901       1.1      76     1
# -----------------------------------------------------------------
# pPXF fit done in 1.15 s
# PIXEL: 166
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -668       377
#  comp.  1:        14         1
#  comp.  2:        25         1
# chi2/DOF: 0.8298; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.9014       1.5      14     1
# Comp:  2           [NII]6583_d     0.9604       1.9      25     1
# -----------------------------------------------------------------
# pPXF fit done in 0.92 s
# PIXEL: 167
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        87         1
#  comp.  1:         5         1
#  comp.  2:        51         1
# chi2/DOF: 0.8553; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 174; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.9942       1.7       5     1
# Comp:  2           [NII]6583_d     0.8102       2.1      51     1
# -----------------------------------------------------------------
# pPXF fit done in 1.58 s
# PIXEL: 168
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       109         1
#  comp.  1:         6         8
#  comp.  2:        10        60
# chi2/DOF: 0.8851; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.149       1.8       6     8
# Comp:  2           [NII]6583_d     0.4689       2.4      10    60
# -----------------------------------------------------------------
# pPXF fit done in 1.11 s
# PIXEL: 169
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       142         1
#  comp.  1:       -11        35
#  comp.  2:       -13        39
# chi2/DOF: 0.9360; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.532       1.8     -11    35
# Comp:  2           [NII]6583_d      1.118       2.3     -13    39
# -----------------------------------------------------------------
# pPXF fit done in 1.17 s
# PIXEL: 170
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       144         1
#  comp.  1:       -14         1
#  comp.  2:         3        65
# chi2/DOF: 0.9540; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.360       1.6     -14     1
# Comp:  2           [NII]6583_d      1.631       2.2       3    65
# -----------------------------------------------------------------
# pPXF fit done in 1.84 s
# PIXEL: 171
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1184       241
#  comp.  1:       -41         1
#  comp.  2:        15        67
# chi2/DOF: 0.9786; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.954       1.2     -41     1
# Comp:  2           [NII]6583_d      1.907       1.6      15    67
# -----------------------------------------------------------------
# pPXF fit done in 1.50 s
# PIXEL: 172
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000      1000
#  comp.  1:       -19        66
#  comp.  2:        11        35
# chi2/DOF: 0.8479; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 228; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.670      0.83     -19    66
# Comp:  2           [NII]6583_d      1.684       1.0      11    35
# -----------------------------------------------------------------
# pPXF fit done in 4.31 s
# PIXEL: 173
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       607       751
#  comp.  1:         7       111
#  comp.  2:        12        62
# chi2/DOF: 0.7372; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.182      0.76       7   111
# Comp:  2           [NII]6583_d      2.717      0.87      12    62
# -----------------------------------------------------------------
# pPXF fit done in 1.21 s
# PIXEL: 174
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       148       947
#  comp.  1:        25       123
#  comp.  2:        18        65
# chi2/DOF: 0.6735; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.340      0.69      25   123
# Comp:  2           [NII]6583_d      2.112      0.77      18    65
# -----------------------------------------------------------------
# pPXF fit done in 1.26 s
# PIXEL: 175
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -140      1000
#  comp.  1:        16       156
#  comp.  2:        10        59
# chi2/DOF: 0.6822; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.216      0.98      16   156
# Comp:  2           [NII]6583_d      1.945       1.0      10    59
# -----------------------------------------------------------------
# pPXF fit done in 0.63 s
# PIXEL: 176
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       532      1000
#  comp.  1:        50       133
#  comp.  2:        36         1
# chi2/DOF: 0.6718; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.810      0.89      50   133
# Comp:  2           [NII]6583_d      1.533      0.92      36     1
# -----------------------------------------------------------------
# pPXF fit done in 0.63 s
# PIXEL: 177
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       575      1000
#  comp.  1:        39       143
#  comp.  2:        33        58
# chi2/DOF: 0.6390; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.446      0.85      39   143
# Comp:  2           [NII]6583_d      1.679      0.91      33    58
# -----------------------------------------------------------------
# pPXF fit done in 0.72 s
# PIXEL: 178
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -475       688
#  comp.  1:        23       135
#  comp.  2:        34        51
# chi2/DOF: 0.5841; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 208; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.206      0.75      23   135
# Comp:  2           [NII]6583_d      1.216      0.81      34    51
# -----------------------------------------------------------------
# pPXF fit done in 1.77 s
# PIXEL: 179
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -943       213
#  comp.  1:        -3       117
#  comp.  2:        35        63
# chi2/DOF: 0.5354; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 17; Func calls: 295; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.823      0.79      -3   117
# Comp:  2           [NII]6583_d      1.443      0.90      35    63
# -----------------------------------------------------------------
# pPXF fit done in 2.72 s
# PIXEL: 180
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -359       842
#  comp.  1:        25       103
#  comp.  2:        55        84
# chi2/DOF: 0.4692; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 226; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.501      0.67      25   103
# Comp:  2           [NII]6583_d      1.705      0.81      55    84
# -----------------------------------------------------------------
# pPXF fit done in 1.92 s
# PIXEL: 181
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -497       782
#  comp.  1:        35        74
#  comp.  2:        76        98
# chi2/DOF: 0.4344; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 192; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.867      0.56      35    74
# Comp:  2           [NII]6583_d      2.045      0.74      76    98
# -----------------------------------------------------------------
# pPXF fit done in 1.67 s
# PIXEL: 182
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -213      1000
#  comp.  1:        41        72
#  comp.  2:        56        89
# chi2/DOF: 0.4414; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.903      0.49      41    72
# Comp:  2           [NII]6583_d      2.548      0.63      56    89
# -----------------------------------------------------------------
# pPXF fit done in 1.13 s
# PIXEL: 183
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -265       948
#  comp.  1:        45        62
#  comp.  2:        44        88
# chi2/DOF: 0.4534; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.377      0.43      45    62
# Comp:  2           [NII]6583_d      3.285      0.57      44    88
# -----------------------------------------------------------------
# pPXF fit done in 1.66 s
# PIXEL: 184
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -97       862
#  comp.  1:        52        62
#  comp.  2:        45        74
# chi2/DOF: 0.2803; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 87; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.927      0.33      52    62
# Comp:  2           [NII]6583_d      4.038      0.43      45    74
# -----------------------------------------------------------------
# pPXF fit done in 0.76 s
# PIXEL: 185
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -37       902
#  comp.  1:        56        66
#  comp.  2:        48        70
# chi2/DOF: 0.2152; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.266      0.37      56    66
# Comp:  2           [NII]6583_d      4.609      0.47      48    70
# -----------------------------------------------------------------
# pPXF fit done in 1.03 s
# PIXEL: 186
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        49       985
#  comp.  1:        59        71
#  comp.  2:        46        78
# chi2/DOF: 0.1584; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 121; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.923      0.43      59    71
# Comp:  2           [NII]6583_d      5.072      0.55      46    78
# -----------------------------------------------------------------
# pPXF fit done in 1.12 s
# PIXEL: 187
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -82       853
#  comp.  1:        65        71
#  comp.  2:        48        79
# chi2/DOF: 0.2037; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 176; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      9.018      0.49      65    71
# Comp:  2           [NII]6583_d      5.035      0.62      48    79
# -----------------------------------------------------------------
# pPXF fit done in 1.87 s
# PIXEL: 188
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        60      1000
#  comp.  1:        68        81
#  comp.  2:        48        81
# chi2/DOF: 0.2972; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 226; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.930      0.56      68    81
# Comp:  2           [NII]6583_d      5.070      0.71      48    81
# -----------------------------------------------------------------
# pPXF fit done in 2.19 s
# PIXEL: 189
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        75      1000
#  comp.  1:        63        90
#  comp.  2:        45       106
# chi2/DOF: 0.3159; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      9.009      0.62      63    90
# Comp:  2           [NII]6583_d      5.180      0.82      45   106
# -----------------------------------------------------------------
# pPXF fit done in 1.38 s
# PIXEL: 190
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -238       556
#  comp.  1:        52       107
#  comp.  2:        37       112
# chi2/DOF: 0.3518; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.893      0.69      52   107
# Comp:  2           [NII]6583_d      5.013      0.89      37   112
# -----------------------------------------------------------------
# pPXF fit done in 1.39 s
# PIXEL: 191
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -231       525
#  comp.  1:        42       115
#  comp.  2:        13       122
# chi2/DOF: 0.3885; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      9.011      0.78      42   115
# Comp:  2           [NII]6583_d      5.093       1.0      13   122
# -----------------------------------------------------------------
# pPXF fit done in 1.31 s
# PIXEL: 192
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       283       715
#  comp.  1:        26       124
#  comp.  2:         5       128
# chi2/DOF: 0.2416; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.810      0.81      26   124
# Comp:  2           [NII]6583_d      5.514       1.0       5   128
# -----------------------------------------------------------------
# pPXF fit done in 1.44 s
# PIXEL: 193
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       228       647
#  comp.  1:        13       121
#  comp.  2:        -5       137
# chi2/DOF: 0.2487; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.822      0.84      13   121
# Comp:  2           [NII]6583_d      5.046       1.1      -5   137
# -----------------------------------------------------------------
# pPXF fit done in 1.06 s
# PIXEL: 194
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -76       673
#  comp.  1:         3       126
#  comp.  2:       -39       114
# chi2/DOF: 0.4089; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.179      0.86       3   126
# Comp:  2           [NII]6583_d      4.036       1.1     -39   114
# -----------------------------------------------------------------
# pPXF fit done in 0.94 s
# PIXEL: 195
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -206       508
#  comp.  1:         6       115
#  comp.  2:       -45       113
# chi2/DOF: 0.7266; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 70; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.204       1.1       6   115
# Comp:  2           [NII]6583_d      3.238       1.4     -45   113
# -----------------------------------------------------------------
# pPXF fit done in 0.61 s
# PIXEL: 196
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -93       423
#  comp.  1:        18       117
#  comp.  2:       -10        97
# chi2/DOF: 0.8691; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 72; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.896       1.4      18   117
# Comp:  2           [NII]6583_d      2.256       1.7     -10    97
# -----------------------------------------------------------------
# pPXF fit done in 0.69 s
# PIXEL: 197
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -84       370
#  comp.  1:       -17       137
#  comp.  2:       -70       117
# chi2/DOF: 0.8935; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.147       1.5     -17   137
# Comp:  2           [NII]6583_d      1.568       1.8     -70   117
# -----------------------------------------------------------------
# pPXF fit done in 0.95 s
# PIXEL: 198
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -41       343
#  comp.  1:        -6       152
#  comp.  2:       -33       102
# chi2/DOF: 0.8993; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.013       1.9      -6   152
# Comp:  2           [NII]6583_d      1.627       2.2     -33   102
# -----------------------------------------------------------------
# pPXF fit done in 1.22 s
# PIXEL: 199
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -25       369
#  comp.  1:        10       138
#  comp.  2:         4        87
# chi2/DOF: 0.8986; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.483       1.8      10   138
# Comp:  2           [NII]6583_d      1.491       2.0       4    87
# -----------------------------------------------------------------
# pPXF fit done in 1.43 s
# PIXEL: 200
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       159       434
#  comp.  1:        23       146
#  comp.  2:      -111       122
# chi2/DOF: 0.8917; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 74; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.533       1.5      23   146
# Comp:  2           [NII]6583_d      1.316       1.8    -111   122
# -----------------------------------------------------------------
# pPXF fit done in 0.85 s
# PIXEL: 201
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -32       501
#  comp.  1:       167       301
#  comp.  2:       -80         1
# chi2/DOF: 0.8529; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 104; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.241       1.7     167   301
# Comp:  2           [NII]6583_d      1.141       1.3     -80     1
# -----------------------------------------------------------------
# pPXF fit done in 1.49 s
# PIXEL: 202
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -410       462
#  comp.  1:       -80        62
#  comp.  2:       -91         1
# chi2/DOF: 0.8031; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 139; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.712      0.83     -80    62
# Comp:  2           [NII]6583_d      1.486      0.98     -91     1
# -----------------------------------------------------------------
# pPXF fit done in 1.80 s
# PIXEL: 203
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        35      1000
#  comp.  1:       -85         1
#  comp.  2:      -209       140
# chi2/DOF: 0.7183; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 173; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.862      0.63     -85     1
# Comp:  2           [NII]6583_d      1.626      0.98    -209   140
# -----------------------------------------------------------------
# pPXF fit done in 2.04 s
# PIXEL: 204
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       101      1000
#  comp.  1:       -46        64
#  comp.  2:      -141         1
# chi2/DOF: 0.8541; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -189       930
#  comp.  1:      -411       316
#  comp.  2:       155       273
# chi2/DOF: 0.7964; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.844       9.0    -411   316
# Comp:  2           [NII]6583_d      1.635       11.     155   273
# -----------------------------------------------------------------
# pPXF fit done in 0.70 s
# PIXEL: 230
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -228         1
#  comp.  1:      -174       488
#  comp.  2:       -15       228
# chi2/DOF: 0.7788; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.148       12.    -174   488
# Comp:  2           [NII]6583_d     0.6842       11.     -15   228
# -----------------------------------------------------------------
# pPXF fit done in 1.05 s
# PIXEL: 231
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -60         1
#  comp.  1:      -138       195
#  comp.  2:       203       235
# chi2/DOF: 0.8009; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.977       7.4    -138   195
# Comp:  2           [NII]6583_d      3.483       10.     203   235
# -----------------------------------------------------------------
# pPXF fit done in 0.48 s
# PIXEL: 232
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -86         1
#  comp.  1:      -293       387
#  comp.  2:       203       259
# chi2/DOF: 0.6943; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.263       10.    -293   387
# Comp:  2           [NII]6583_d      2.857       11.     203   259
# -----------------------------------------------------------------
# pPXF fit done in 1.09 s
# PIXEL: 233
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       -36         1
#  comp.  1:      -239       280
#  comp.  2:        89       416
# chi2/DOF: 0.7339; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.406       6.8    -239   280
# Comp:  2           [NII]6583_d      5.537       10.      89   416
# -----------------------------------------------------------------
# pPXF fit done in 0.86 s
# PIXEL: 234
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:        -6         1
#  comp.  1:       247       444
#  comp.  2:       601       394
# chi2/DOF: 0.7288; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 91; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.638       7.7     247   444
# Comp:  2           [NII]6583_d      7.059       9.1     601   394
# -----------------------------------------------------------------
# pPXF fit done in 0.86 s
# PIXEL: 235
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1456       222
#  comp.  1:      2000      1000
#  comp.  2:       231       252
# chi2/DOF: 0.7480; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.93       13.    2000  1000
# Comp:  2           [NII]6583_d      6.759       8.5     231   252
# -----------------------------------------------------------------
# pPXF fit done in 1.58 s
# PIXEL: 236
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1649       332
#  comp.  1:         0       200
#  comp.  2:       361       535
# chi2/DOF: 0.7489; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       6.2       0   200
# Comp:  2           [NII]6583_d      16.94       12.     361   535
# -----------------------------------------------------------------
# pPXF fit done in 1.57 s
# PIXEL: 237
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1250         1
#  comp.  1:         0       200
#  comp.  2:       270       615
# chi2/DOF: 0.7585; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 88; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       6.9       0   200
# Comp:  2           [NII]6583_d      17.18       13.     270   615
# -----------------------------------------------------------------
# pPXF fit done in 0.78 s
# PIXEL: 238
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1289         1
#  comp.  1:        -0       200
#  comp.  2:       -44       341
# chi2/DOF: 0.8184; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       7.3      -0   200
# Comp:  2           [NII]6583_d      10.24       11.     -44   341
# -----------------------------------------------------------------
# pPXF fit done in 1.00 s
# PIXEL: 239
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -1272         1
#  comp.  1:        -0       200
#  comp.  2:       -20       412
# chi2/DOF: 0.8913; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 106; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       7.8      -0   200
# Comp:  2           [NII]6583_d      6.943       13.     -20   412
# -----------------------------------------------------------------
# pPXF fit done in 1.17 s
# PIXEL: 240
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     -2000       474
#  comp.  1:        -0       200
#  comp.  2:        49       275
# chi2/DOF: 0.8336; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       7.7      -0   200
# Comp:  2           [NII]6583_d      3.197       11.      49   275
# -----------------------------------------------------------------
# pPXF fit done in 0.99 s
# PIXEL: 241
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      -411       114
#  comp.  1:       346        15
#  comp.  2:         0       200
# chi2/DOF: 0.8797; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 177; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.705       4.7     346    15
# Comp:  2           [NII]6583_d      0.000       8.3       0   200
# -----------------------------------------------------------------
# pPXF fit done in 5.94 s
# PIXEL: 242
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1552         1
#  comp.  1:        -0       200
#  comp.  2:        32       197
# chi2/DOF: 1.141; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 146; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       13.      -0   200
# Comp:  2           [NII]6583_d      1.518       17.      32   197
# -----------------------------------------------------------------
# pPXF fit done in 1.72 s
# PIXEL: 243
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1036         4
#  comp.  1:       265       117
#  comp.  2:        72       197
# chi2/DOF: 1.039; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.441       12.     265   117
# Comp:  2           [NII]6583_d      5.473       18.      72   197
# -----------------------------------------------------------------
# pPXF fit done in 1.21 s
# PIXEL: 244
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      1063         1
#  comp.  1:       545       553
#  comp.  2:        -0       200
# chi2/DOF: 1.054; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 53; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.55       33.     545   553
# Comp:  2           [NII]6583_d      0.000       27.      -0   200
# -----------------------------------------------------------------
# pPXF fit done in 0.56 s
# PIXEL: 245
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       741       222
#  comp.  1:       324       239
#  comp.  2:         0       200
# chi2/DOF: 0.8594; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.339       17.     324   239
# Comp:  2           [NII]6583_d      0.000       20.       0   200
# -----------------------------------------------------------------
# pPXF fit done in 1.18 s
# PIXEL: 246
# Emission lines included in gas templates:
# ['Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731' 'HeII4687'
#  'HeI5876' '[OIII]5007_d' '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:       437         1
#  comp.  1:       361       302
#  comp.  2:         9       201
# chi2/DOF: 0.8660; DOF: 1615; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 89; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.618       21.     361   302
# Comp:  2           [NII]6583_d      0.000       23.       9   201
# -----------------------------------------------------------------
# pPXF fit done in 2.35 s
# PIXEL: 247

# %%
# raw.shape == (n_wave, n_spatial)
spatial_flux = raw.sum(axis=0)       # total flux in each slit column
slit_pixels  = np.arange(raw.shape[1])

# Only look between 150 and 250
search_range = slice(150, 251)
peak_rel = np.argmax(spatial_flux[search_range])
peak = slit_pixels[search_range][peak_rel]

print(f"Peak flux at {peak} px")

plt.figure(figsize=(8, 4))
plt.axvline(peak, color='green', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
plt.axvline(175, color='red', linestyle='--', linewidth=1)
plt.axvline(215, color='red', linestyle='--', linewidth=1)
plt.scatter(slit_pixels, spatial_flux, s=10)
plt.xlabel("Slit Pixel")
plt.ylabel("Integrated Flux")
plt.title("Flux vs. Slit Position")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Peak flux at 186 px

# %%
for center, df_rb, pp in results[25:100]:
    # Ensure the function can access 'lam'
    lam_array = df_rb['lam'].values
    plot_ppxf.__globals__['lam'] = lam_array

    print(f"Window centre: {center}")
    plot_ppxf(df_rb, pp)

    # Extract and print the Hα sigma (km/s)
    sigma = pp.sol[1][1]
    print(f"σ (km/s): {sigma:.2f}\n")
# Out:
# Window centre: 177
# σ (km/s): 132.66
#
# Window centre: 178
# σ (km/s): 142.86
#
# Window centre: 179
# σ (km/s): 135.39
#
# Window centre: 180
# σ (km/s): 117.42
#
# Window centre: 181
# σ (km/s): 103.49
#
# Window centre: 182
# σ (km/s): 74.45
#
# Window centre: 183
# σ (km/s): 71.51
#
# Window centre: 184
# σ (km/s): 61.55
#
# Window centre: 185
# σ (km/s): 62.28
#
# Window centre: 186
# σ (km/s): 66.32
#
# Window centre: 187
# σ (km/s): 70.82
#
# Window centre: 188
# σ (km/s): 70.85
#
# Window centre: 189
# σ (km/s): 81.13
#
# Window centre: 190
# σ (km/s): 90.29
#
# Window centre: 191
# σ (km/s): 106.76
#
# Window centre: 192
# σ (km/s): 115.44
#
# Window centre: 193
# σ (km/s): 124.23
#
# Window centre: 194
# σ (km/s): 120.93
#
# Window centre: 195
# σ (km/s): 126.15
#
# Window centre: 196
# σ (km/s): 114.55
#
# Window centre: 197
# σ (km/s): 117.41
#
# Window centre: 198
# σ (km/s): 136.85
#
# Window centre: 199
# σ (km/s): 152.08
#
# Window centre: 200
# σ (km/s): 138.24
#
# Window centre: 201
# σ (km/s): 145.58
#
# Window centre: 202
# σ (km/s): 300.66
#
# Window centre: 203
# σ (km/s): 61.58
#
# Window centre: 204
# σ (km/s): 1.03
#
# Window centre: 205
# σ (km/s): 64.28
#
# Window centre: 206
# σ (km/s): 72.03
#
# Window centre: 207
# σ (km/s): 76.44
#
# Window centre: 208
# σ (km/s): 101.99
#
# Window centre: 209
# σ (km/s): 125.59
#
# Window centre: 210
# σ (km/s): 97.84
#
# Window centre: 211
# σ (km/s): 121.27
#
# Window centre: 212
# σ (km/s): 221.75
#
# Window centre: 213
# σ (km/s): 255.88
#
# Window centre: 214
# σ (km/s): 356.76
#
# Window centre: 215
# σ (km/s): 393.11
#
# Window centre: 216
# σ (km/s): 406.92
#
# Window centre: 217
# σ (km/s): 224.53
#
# Window centre: 218
# σ (km/s): 161.26
#
# Window centre: 219
# σ (km/s): 81.27
#
# Window centre: 220
# σ (km/s): 50.45
#
# Window centre: 221
# σ (km/s): 53.53
#
# Window centre: 222
# σ (km/s): 25.01
#
# Window centre: 223
# σ (km/s): 70.53
#
# Window centre: 224
# σ (km/s): 52.92
#
# Window centre: 225
# σ (km/s): 89.37
#
# Window centre: 226
# σ (km/s): 108.16
#
# Window centre: 227
# σ (km/s): 86.47
#
# Window centre: 228
# σ (km/s): 1.03
#
# Window centre: 229
# σ (km/s): 119.49
#
# Window centre: 230
# σ (km/s): 315.76
#
# Window centre: 231
# σ (km/s): 488.05
#
# Window centre: 232
# σ (km/s): 194.68
#
# Window centre: 233
# σ (km/s): 387.38
#
# Window centre: 234
# σ (km/s): 279.64
#
# Window centre: 235
# σ (km/s): 444.03
#
# Window centre: 236
# σ (km/s): 1000.00
#
# Window centre: 237
# σ (km/s): 200.00
#
# Window centre: 238
# σ (km/s): 200.00
#
# Window centre: 239
# σ (km/s): 200.00
#
# Window centre: 240
# σ (km/s): 200.00
#
# Window centre: 241
# σ (km/s): 200.00
#
# Window centre: 242
# σ (km/s): 15.31
#
# Window centre: 243
# σ (km/s): 200.00
#
# Window centre: 244
# σ (km/s): 116.70
#
# Window centre: 245
# σ (km/s): 552.92
#
# Window centre: 246
# σ (km/s): 238.66
#
# Window centre: 247
# σ (km/s): 302.00

# %%
centers     = []
velocities  = []; v_errs     = []
dispersions = []; sigma_errs = []
EWs         = []; EW_errs    = []

for center, _, pp in results:
    # --- extract Hα kinematics from the list ---
    sol_gas    = pp.sol[1]
    err_gas    = pp.error[1]
    v_ha, sigma_ha       = sol_gas
    #sigma = np.sqrt(sigma_inst**2 + sigma_ha**2)

    v_ha_err, sigma_ha_err = err_gas

    # find Hα in gas_names (should be idx 0 here)
    idx = np.where(pp.gas_names == "Halpha")[0][0]

    # compute flux, continuum & EW as before
    flux_ha   = pp.gas_flux[idx]
    continuum = pp.bestfit - pp.gas_bestfit
    peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
    cont0     = continuum[peak_i]
    cont_err  = pp.noise[peak_i]
    flux_err  = pp.gas_flux_error[idx]

    EW        = flux_ha / cont0
    EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

    # store
    centers.append(center)
    velocities.append(v_ha)
    v_errs.append(v_ha_err)
    dispersions.append(sigma_ha)
    sigma_errs.append(sigma_ha_err)
    EWs.append(EW)
    EW_errs.append(EW_err)
# Out:
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_26755/3518839896.py:27: RuntimeWarning: divide by zero encountered in scalar divide
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_26755/3518839896.py:27: RuntimeWarning: invalid value encountered in scalar multiply
#   EW_err    = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

# %%
fig, axs = plt.subplots(3,1,figsize=(10,9),sharex=True)

colors = ['#1f77b4', '#2ca02c', '#d62728']  # blue, green, red

# Velocity
axs[0].errorbar(centers, velocities, yerr=v_errs,
                fmt='o', ecolor=colors[0], color=colors[0],
                capsize=3, label='Hα Velocity')
axs[0].set_ylim(-250,250)
axs[0].set_ylabel("Velocity (km/s)")
axs[0].set_title("Hα Velocity vs. Slit Position")
axs[0].axvline(peak, color='hotpink', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
#axs[0].axvline(175, color='red', ls='--', lw=1)
#axs[0].axvline(215, color='red', ls='--', lw=1)
axs[0].legend(); axs[0].grid(True)

# Dispersion
axs[1].errorbar(centers, dispersions, yerr=sigma_errs,
                fmt='o', ecolor=colors[1], color=colors[1],
                capsize=3, label='Hα σ')
axs[1].set_ylim(-100,300)
axs[1].set_ylabel("σ (km/s)")
axs[1].set_title("Hα σ vs. Slit Position")
axs[1].axvline(peak, color='hotpink', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
#axs[1].axvline(175, color='red', ls='--', lw=1)
#axs[1].axvline(215, color='red', ls='--', lw=1)
axs[1].legend(); axs[1].grid(True)

# Equivalent Width
axs[2].errorbar(centers, EWs, yerr = EW_errs,
                fmt='o', ecolor=colors[2], color=colors[2],
                capsize=3, label='Hα EW')
axs[2].set_ylim(-20,40)
axs[2].set_ylabel("EW (Å)")
axs[2].set_xlabel("Slit Position (arcsec)")
axs[2].set_title("Hα EW vs. Slit Position")
axs[2].axvline(peak, color='hotpink', linestyle='--', linewidth=1,
            label=f'Peak ({peak})')
#axs[2].axvline(175, color='red', ls='--', lw=1)
#axs[2].axvline(215, color='red', ls='--', lw=1)
axs[2].legend(); axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame({
    'center':        centers,
    'velocity':      velocities,
    'velocity_err':  v_errs,
    'dispersion':    dispersions,
    'dispersion_err': sigma_errs,
    'EW':            EWs,
    'EW_err':        EW_errs
})

df.to_csv('../halpha results/SB6_orth_halpha_results.csv', index=False)
