# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions_Z import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,
)

# %%
# --- Inputs ---
galaxy_files = [
    (f"../calibrated data/SB{i}_data.npy", f"../calibrated data/SB{i}_waveobs.npy")
    for i in range(1, 8)
]

# Match each dataset to its redshift (same order)
redshifts = [
    0.017206345, 
    0.038136434,
    0.041185744,
    0.045207640,
    0.042784720,
    0.017624998,
    0.046458002
]

# %%
window_size = 10
step        = 1
scale       = 0.4   # arcsec per pixel
pix_min, pix_max = 150, 250

all_results = {}

# --- Loop over galaxies ---
for (data_file, wave_file), z in zip(galaxy_files, redshifts):

    print(f"\nRunning galaxy {data_file} with z={z}")

    raw = np.load(data_file)       # flux × spatial pixel
    waveem = np.load(wave_file)

    results = []
    raw_roi = raw[:, pix_min:pix_max]

    for start in range(0, raw_roi.shape[1] - window_size + 1, step):
        end = start + window_size
        spectrum = raw_roi[:, start:end].sum(axis=1)

        # Build DataFrame
        df_spec = pd.DataFrame({
            "waveem": waveem,
            "flux":   spectrum
        })

        # Process, rebin, noise
        df_cut = process_spectrum(df_spec)
        df_rb, lam, flux_rb, ln_w = rebin_to_log(df_cut)

        noise = make_noise(df_rb)
        velscale, fwhm = calculate_velscale_fwhm(ln_w, lam)
        center = start + window_size//2 + pix_min

        # Run pPXF with galaxy's redshift
        pp = run_ppxf(lam, fwhm, velscale, df_rb, noise, redshift=z)

        print(f'  PIXEL: {center}')

        # Store result
        results.append((center, df_rb, pp))

    # Save per galaxy
    all_results[data_file] = results
# Out:
# Running galaxy ../calibrated results/SB1_data.npy with z=0.017206345
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3348      1000
#  comp.  1:      4857       145
# chi2/DOF: 0.1951; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 228; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.182      0.86    4857   145
# Comp:  1           [NII]6583_d      2.273       1.1    4857   145
# -----------------------------------------------------------------
#   PIXEL: 155
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3631      1000
#  comp.  1:      4840       126
# chi2/DOF: 0.1797; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 184; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.698      0.84    4840   126
# Comp:  1           [NII]6583_d      1.825       1.1    4840   126
# -----------------------------------------------------------------
#   PIXEL: 156
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3611      1000
#  comp.  1:      4832       130
# chi2/DOF: 0.1749; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 168; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.152      0.85    4832   130
# Comp:  1           [NII]6583_d      1.300       1.1    4832   130
# -----------------------------------------------------------------
#   PIXEL: 157
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3516      1000
#  comp.  1:      5016       484
# chi2/DOF: 0.1653; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 167; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.1245       1.7    5016   484
# Comp:  1           [NII]6583_d      2.488       2.1    5016   484
# -----------------------------------------------------------------
#   PIXEL: 158
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3556      1000
#  comp.  1:      5254       399
# chi2/DOF: 0.1544; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 182; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.4    5254   399
# Comp:  1           [NII]6583_d      1.757       1.8    5254   399
# -----------------------------------------------------------------
#   PIXEL: 159
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3454      1000
#  comp.  1:      5254       353
# chi2/DOF: 0.1501; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 182; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.3    5254   353
# Comp:  1           [NII]6583_d      1.242       1.6    5254   353
# -----------------------------------------------------------------
#   PIXEL: 160
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5295       294
# chi2/DOF: 0.1559; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 16; Func calls: 242; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.1    5295   294
# Comp:  1           [NII]6583_d     0.6140       1.4    5295   294
# -----------------------------------------------------------------
#   PIXEL: 161
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5174         1
# chi2/DOF: 0.3193; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 16; Func calls: 242; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.78    5174     1
# Comp:  1           [NII]6583_d     0.2316      0.99    5174     1
# -----------------------------------------------------------------
#   PIXEL: 162
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5190         1
# chi2/DOF: 0.3428; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 294; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.80    5190     1
# Comp:  1           [NII]6583_d    0.02787       1.0    5190     1
# -----------------------------------------------------------------
#   PIXEL: 163
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5174         1
# chi2/DOF: 0.3754; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 17; Func calls: 260; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.82    5174     1
# Comp:  1           [NII]6583_d    0.06961       1.0    5174     1
# -----------------------------------------------------------------
#   PIXEL: 164
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3945      1000
#  comp.  1:      5011         1
# chi2/DOF: 0.3957; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.85    5011     1
# Comp:  1           [NII]6583_d      0.000       1.1    5011     1
# -----------------------------------------------------------------
#   PIXEL: 165
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3842      1000
#  comp.  1:      5153         1
# chi2/DOF: 0.3867; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 138; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.84    5153     1
# Comp:  1           [NII]6583_d      0.000       1.1    5153     1
# -----------------------------------------------------------------
#   PIXEL: 166
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3808      1000
#  comp.  1:      5115         1
# chi2/DOF: 0.3808; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.83    5115     1
# Comp:  1           [NII]6583_d      0.000       1.0    5115     1
# -----------------------------------------------------------------
#   PIXEL: 167
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3860      1000
#  comp.  1:      5187         3
# chi2/DOF: 0.3702; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000      0.82    5187     3
# Comp:  1           [NII]6583_d      0.000       1.0    5187     3
# -----------------------------------------------------------------
#   PIXEL: 168
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3877      1000
#  comp.  1:      5154       269
# chi2/DOF: 0.3631; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.3    5154   269
# Comp:  1           [NII]6583_d    0.09847       1.7    5154   269
# -----------------------------------------------------------------
#   PIXEL: 169
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3894      1000
#  comp.  1:      5170       263
# chi2/DOF: 0.3514; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.3    5170   263
# Comp:  1           [NII]6583_d     0.2686       1.6    5170   263
# -----------------------------------------------------------------
#   PIXEL: 170
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3814      1000
#  comp.  1:      5012       176
# chi2/DOF: 0.2771; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.0    5012   176
# Comp:  1           [NII]6583_d     0.4105       1.3    5012   176
# -----------------------------------------------------------------
#   PIXEL: 171
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3721      1000
#  comp.  1:      5062       308
# chi2/DOF: 0.1084; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 169; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.2    5062   308
# Comp:  1           [NII]6583_d     0.7970       1.5    5062   308
# -----------------------------------------------------------------
#   PIXEL: 172
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3732      1000
#  comp.  1:      5100       295
# chi2/DOF: 0.09511; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 199; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.1    5100   295
# Comp:  1           [NII]6583_d      1.186       1.4    5100   295
# -----------------------------------------------------------------
#   PIXEL: 173
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3936      1000
#  comp.  1:      5109       316
# chi2/DOF: 0.08274; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.2    5109   316
# Comp:  1           [NII]6583_d      1.362       1.5    5109   316
# -----------------------------------------------------------------
#   PIXEL: 174
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3860      1000
#  comp.  1:      5216       321
# chi2/DOF: 0.07666; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 152; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.1    5216   321
# Comp:  1           [NII]6583_d      1.616       1.4    5216   321
# -----------------------------------------------------------------
#   PIXEL: 175
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      4117      1000
#  comp.  1:      5261       315
# chi2/DOF: 0.07376; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       1.1    5261   315
# Comp:  1           [NII]6583_d      1.706       1.4    5261   315
# -----------------------------------------------------------------
#   PIXEL: 176
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      4122      1000
#  comp.  1:      5267       335
# chi2/DOF: 0.06849; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha    0.08143       1.1    5267   335
# Comp:  1           [NII]6583_d      1.977       1.4    5267   335
# -----------------------------------------------------------------
#   PIXEL: 177
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      4065      1000
#  comp.  1:      5212       331
# chi2/DOF: 0.06530; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 229; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.3990       1.1    5212   331
# Comp:  1           [NII]6583_d      1.899       1.4    5212   331
# -----------------------------------------------------------------
#   PIXEL: 178
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      4019      1000
#  comp.  1:      5083       391
# chi2/DOF: 0.06097; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 157; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.9064       1.2    5083   391
# Comp:  1           [NII]6583_d      1.996       1.5    5083   391
# -----------------------------------------------------------------
#   PIXEL: 179
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3490      1000
#  comp.  1:      4615       986
# chi2/DOF: 0.06043; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 292; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.2766       3.9    4615   986
# Comp:  1           [NII]6583_d      4.877       4.3    4615   986
# -----------------------------------------------------------------
#   PIXEL: 180
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3332      1000
#  comp.  1:      5163       390
# chi2/DOF: 0.06147; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 227; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.317       1.0    5163   390
# Comp:  1           [NII]6583_d      2.841       1.3    5163   390
# -----------------------------------------------------------------
#   PIXEL: 181
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5313       252
# chi2/DOF: 0.06551; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 197; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.393      0.71    5313   252
# Comp:  1           [NII]6583_d      3.314      0.90    5313   252
# -----------------------------------------------------------------
#   PIXEL: 182
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5342       218
# chi2/DOF: 0.06919; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 188; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.027      0.61    5342   218
# Comp:  1           [NII]6583_d      4.135      0.77    5342   218
# -----------------------------------------------------------------
#   PIXEL: 183
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5341       198
# chi2/DOF: 0.06492; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.916      0.57    5341   198
# Comp:  1           [NII]6583_d      5.172      0.71    5341   198
# -----------------------------------------------------------------
#   PIXEL: 184
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5326       197
# chi2/DOF: 0.05805; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.971      0.58    5326   197
# Comp:  1           [NII]6583_d      6.283      0.74    5326   197
# -----------------------------------------------------------------
#   PIXEL: 185
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5308       200
# chi2/DOF: 0.04842; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 152; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.01      0.64    5308   200
# Comp:  1           [NII]6583_d      7.353      0.81    5308   200
# -----------------------------------------------------------------
#   PIXEL: 186
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5287       204
# chi2/DOF: 0.03847; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 185; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.71      0.70    5287   204
# Comp:  1           [NII]6583_d      8.187      0.89    5287   204
# -----------------------------------------------------------------
#   PIXEL: 187
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5266       206
# chi2/DOF: 0.03154; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 171; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      14.28      0.79    5266   206
# Comp:  1           [NII]6583_d      9.145      0.99    5266   206
# -----------------------------------------------------------------
#   PIXEL: 188
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5248       204
# chi2/DOF: 0.03383; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 291; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      15.65      0.87    5248   204
# Comp:  1           [NII]6583_d      10.09       1.1    5248   204
# -----------------------------------------------------------------
#   PIXEL: 189
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5232       203
# chi2/DOF: 0.03337; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 182; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      16.75      0.94    5232   203
# Comp:  1           [NII]6583_d      10.82       1.2    5232   203
# -----------------------------------------------------------------
#   PIXEL: 190
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5223       201
# chi2/DOF: 0.03015; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 200; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      17.63       1.0    5223   201
# Comp:  1           [NII]6583_d      11.41       1.3    5223   201
# -----------------------------------------------------------------
#   PIXEL: 191
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5214       199
# chi2/DOF: 0.02745; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 20; Func calls: 306; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      18.42       1.1    5214   199
# Comp:  1           [NII]6583_d      11.88       1.4    5214   199
# -----------------------------------------------------------------
#   PIXEL: 192
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5205       196
# chi2/DOF: 0.02553; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 292; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      18.93       1.1    5205   196
# Comp:  1           [NII]6583_d      12.19       1.5    5205   196
# -----------------------------------------------------------------
#   PIXEL: 193
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3114      1000
#  comp.  1:      5192       192
# chi2/DOF: 0.02428; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 217; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      19.30       1.2    5192   192
# Comp:  1           [NII]6583_d      12.53       1.6    5192   192
# -----------------------------------------------------------------
#   PIXEL: 194
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3206      1000
#  comp.  1:      5179       187
# chi2/DOF: 0.02340; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 234; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      19.50       1.3    5179   187
# Comp:  1           [NII]6583_d      12.70       1.7    5179   187
# -----------------------------------------------------------------
#   PIXEL: 195
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3386      1000
#  comp.  1:      5163       181
# chi2/DOF: 0.02404; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 16; Func calls: 242; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      19.08       1.4    5163   181
# Comp:  1           [NII]6583_d      12.63       1.8    5163   181
# -----------------------------------------------------------------
#   PIXEL: 196
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3713      1000
#  comp.  1:      5150       174
# chi2/DOF: 0.02599; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 197; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      18.34       1.5    5150   174
# Comp:  1           [NII]6583_d      12.49       1.8    5150   174
# -----------------------------------------------------------------
#   PIXEL: 197
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3880      1000
#  comp.  1:      5139       171
# chi2/DOF: 0.03132; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 291; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      16.50       1.5    5139   171
# Comp:  1           [NII]6583_d      11.51       1.8    5139   171
# -----------------------------------------------------------------
#   PIXEL: 198
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3739      1000
#  comp.  1:      5131       175
# chi2/DOF: 0.02295; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 212; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      13.84       1.4    5131   175
# Comp:  1           [NII]6583_d      9.820       1.8    5131   175
# -----------------------------------------------------------------
#   PIXEL: 199
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      4070      1000
#  comp.  1:      5123       186
# chi2/DOF: 0.01803; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 18; Func calls: 275; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.65       1.4    5123   186
# Comp:  1           [NII]6583_d      7.781       1.7    5123   186
# -----------------------------------------------------------------
#   PIXEL: 200
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3982      1000
#  comp.  1:      5116       200
# chi2/DOF: 0.02151; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 16; Func calls: 245; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.588       1.3    5116   200
# Comp:  1           [NII]6583_d      5.924       1.7    5116   200
# -----------------------------------------------------------------
#   PIXEL: 201
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3931      1000
#  comp.  1:      5105       226
# chi2/DOF: 0.02665; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 152; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.904       1.3    5105   226
# Comp:  1           [NII]6583_d      4.521       1.6    5105   226
# -----------------------------------------------------------------
#   PIXEL: 202
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3998      1000
#  comp.  1:      5071       278
# chi2/DOF: 0.03134; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 152; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.306       1.3    5071   278
# Comp:  1           [NII]6583_d      3.803       1.7    5071   278
# -----------------------------------------------------------------
#   PIXEL: 203
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3785      1000
#  comp.  1:      4954      1000
# chi2/DOF: 0.03163; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 227; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.908       5.6    4954  1000
# Comp:  1           [NII]6583_d      4.961       6.2    4954  1000
# -----------------------------------------------------------------
#   PIXEL: 204
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3752      1000
#  comp.  1:      4806      1000
# chi2/DOF: 0.03575; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 182; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.386       5.5    4806  1000
# Comp:  1           [NII]6583_d      4.702       6.0    4806  1000
# -----------------------------------------------------------------
#   PIXEL: 205
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3768      1000
#  comp.  1:      4929      1000
# chi2/DOF: 0.03921; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 167; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.165       5.4    4929  1000
# Comp:  1           [NII]6583_d      4.039       5.9    4929  1000
# -----------------------------------------------------------------
#   PIXEL: 206
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3748      1000
#  comp.  1:      4656      1000
# chi2/DOF: 0.04352; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 197; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.452       5.3    4656  1000
# Comp:  1           [NII]6583_d      3.003       5.9    4656  1000
# -----------------------------------------------------------------
#   PIXEL: 207
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3844      1000
#  comp.  1:      4566      1000
# chi2/DOF: 0.04721; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 229; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.603       5.3    4566  1000
# Comp:  1           [NII]6583_d      1.688       5.8    4566  1000
# -----------------------------------------------------------------
#   PIXEL: 208
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3983      1000
#  comp.  1:      4530      1000
# chi2/DOF: 0.04846; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 172; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.098       5.2    4530  1000
# Comp:  1           [NII]6583_d      1.829       5.8    4530  1000
# -----------------------------------------------------------------
#   PIXEL: 209
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      3955      1000
#  comp.  1:      4176      1000
# chi2/DOF: 0.05308; DOF: 1586; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# ...
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       28.   13614   120
# Comp:  1           [NII]6583_d      0.000       35.   13614   120
# -----------------------------------------------------------------
#   PIXEL: 227
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     14740         1
#  comp.  1:     13548       113
# chi2/DOF: 0.9778; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 155; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       60.   13548   113
# Comp:  1           [NII]6583_d      32.45       76.   13548   113
# -----------------------------------------------------------------
#   PIXEL: 228
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     14686         1
#  comp.  1:     13318         1
# chi2/DOF: 0.9799; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 200; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       43.   13318     1
# Comp:  1           [NII]6583_d      76.85       54.   13318     1
# -----------------------------------------------------------------
#   PIXEL: 229
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     13614       120
#  comp.  1:     13529       308
# chi2/DOF: 1.000; DOF: 1599; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      381.6   1.4e+02   13529   308
# Comp:  1           [NII]6583_d      0.000   1.8e+02   13529   308
# -----------------------------------------------------------------
#   PIXEL: 230
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     13614       120
#  comp.  1:     13496       255
# chi2/DOF: 0.9994; DOF: 1599; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 47; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      335.6   1.1e+02   13496   255
# Comp:  1           [NII]6583_d      0.000   1.4e+02   13496   255
# -----------------------------------------------------------------
#   PIXEL: 231
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11614       549
#  comp.  1:     13614       120
# chi2/DOF: 0.9885; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       78.   13614   120
# Comp:  1           [NII]6583_d      0.000       98.   13614   120
# -----------------------------------------------------------------
#   PIXEL: 232
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     13452      1000
#  comp.  1:     13614       120
# chi2/DOF: 0.9892; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 81; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.5e+02   13614   120
# Comp:  1           [NII]6583_d      0.000   1.8e+02   13614   120
# -----------------------------------------------------------------
#   PIXEL: 233
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     14686         1
#  comp.  1:     13614       120
# chi2/DOF: 0.9865; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       49.   13614   120
# Comp:  1           [NII]6583_d      0.000       62.   13614   120
# -----------------------------------------------------------------
#   PIXEL: 234
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     14672         1
#  comp.  1:     13614       120
# chi2/DOF: 0.9875; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       35.   13614   120
# Comp:  1           [NII]6583_d      0.000       44.   13614   120
# -----------------------------------------------------------------
#   PIXEL: 235
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     13962       829
#  comp.  1:     13614       120
# chi2/DOF: 0.9903; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 3; Func calls: 51; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       44.   13614   120
# Comp:  1           [NII]6583_d      0.000       56.   13614   120
# -----------------------------------------------------------------
#   PIXEL: 236
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     12323         1
#  comp.  1:     13614       120
# chi2/DOF: 0.9870; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   4.4e+02   13614   120
# Comp:  1           [NII]6583_d      0.000   5.6e+02   13614   120
# -----------------------------------------------------------------
#   PIXEL: 237
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11685         1
#  comp.  1:     13614       120
# chi2/DOF: 0.9828; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000   1.6e+02   13614   120
# Comp:  1           [NII]6583_d      0.000   2.0e+02   13614   120
# -----------------------------------------------------------------
#   PIXEL: 238
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11617         1
#  comp.  1:     13638       154
# chi2/DOF: 0.9955; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 11; Func calls: 175; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      140.8       53.   13638   154
# Comp:  1           [NII]6583_d      72.69       67.   13638   154
# -----------------------------------------------------------------
#   PIXEL: 239
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11631         1
#  comp.  1:     13592         1
# chi2/DOF: 0.9967; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      45.42       28.   13592     1
# Comp:  1           [NII]6583_d      42.81       35.   13592     1
# -----------------------------------------------------------------
#   PIXEL: 240
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     13030       707
#  comp.  1:     13710       134
# chi2/DOF: 0.9953; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 129; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      39.64       30.   13710   134
# Comp:  1           [NII]6583_d      60.92       38.   13710   134
# -----------------------------------------------------------------
#   PIXEL: 241
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11892      1000
#  comp.  1:     13679       151
# chi2/DOF: 0.9864; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      26.19       17.   13679   151
# Comp:  1           [NII]6583_d      20.32       21.   13679   151
# -----------------------------------------------------------------
#   PIXEL: 242
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11881       927
#  comp.  1:     13558       137
# chi2/DOF: 0.9850; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      16.60       13.   13558   137
# Comp:  1           [NII]6583_d      7.255       17.   13558   137
# -----------------------------------------------------------------
#   PIXEL: 243
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     13228       709
#  comp.  1:     13632       206
# chi2/DOF: 0.9761; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      14.50       10.   13632   206
# Comp:  1           [NII]6583_d      6.477       13.   13632   206
# -----------------------------------------------------------------
#   PIXEL: 244
# Emission lines included in gas templates:
# ['H9' 'H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[NeIII]3968'
#  '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     12836      1000
#  comp.  1:     13634       190
# chi2/DOF: 0.9688; DOF: 1588; degree = -1; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 97; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.735       9.0   13634   190
# Comp:  1           [NII]6583_d     0.7911       11.   13634   190
# -----------------------------------------------------------------
#   PIXEL: 245

# %%
import os
save_dir = "../halpha_results_Z"
os.makedirs(save_dir, exist_ok=True)

for data_file, results in all_results.items():
    galaxy_name = os.path.basename(data_file).replace("_data.npy", "")

    centers, velocities, v_errs, dispersions, sigma_errs, EWs, EW_errs = [], [], [], [], [], [], []

    for center, df_rb, pp in results:
        # --- extract Hα kinematics ---
        sol_gas = pp.sol[1]
        err_gas = pp.error[1]
        v_ha, sigma_ha = sol_gas
        v_ha_err, sigma_ha_err = err_gas

        # Hα index in gas templates
        idx = np.where(pp.gas_names == "Halpha")[0][0]

        flux_ha   = pp.gas_flux[idx]
        continuum = pp.bestfit - pp.gas_bestfit
        peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
        cont0     = continuum[peak_i]
        cont_err  = pp.noise[peak_i]
        flux_err  = pp.gas_flux_error[idx]

        EW     = flux_ha / cont0
        EW_err = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

        # store
        centers.append(center)
        velocities.append(v_ha)
        v_errs.append(v_ha_err)
        dispersions.append(sigma_ha)
        sigma_errs.append(sigma_ha_err)
        EWs.append(EW)
        EW_errs.append(EW_err)

    # Build DataFrame
    df = pd.DataFrame({
        "center":        centers,
        "velocity":      velocities,
        "velocity_err":  v_errs,
        "dispersion":    dispersions,
        "dispersion_err": sigma_errs,
        "EW":            EWs,
        "EW_err":        EW_errs
    })

    # Save one CSV per galaxy
    out_path = os.path.join(save_dir, f"{galaxy_name}_halpha_results.csv")
    df.to_csv(out_path, index=False)
    print(f"Saved {out_path}")
# Out:
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_29161/2878549075.py:28: RuntimeWarning: divide by zero encountered in scalar divide
#   EW_err = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_29161/2878549075.py:28: RuntimeWarning: invalid value encountered in scalar multiply
#   EW_err = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# Saved ../halpha_results_Z/SB1_halpha_results.csv
# Saved ../halpha_results_Z/SB2_halpha_results.csv
# Saved ../halpha_results_Z/SB3_halpha_results.csv
# Saved ../halpha_results_Z/SB4_halpha_results.csv
# Saved ../halpha_results_Z/SB5_halpha_results.csv
# Saved ../halpha_results_Z/SB6_halpha_results.csv
# Saved ../halpha_results_Z/SB7_halpha_results.csv
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_29161/2878549075.py:27: RuntimeWarning: invalid value encountered in scalar divide
#   EW     = flux_ha / cont0
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_29161/2878549075.py:27: RuntimeWarning: divide by zero encountered in scalar divide
#   EW     = flux_ha / cont0
