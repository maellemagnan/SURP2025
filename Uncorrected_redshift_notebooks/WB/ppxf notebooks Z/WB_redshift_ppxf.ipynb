# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ppxf_functions_Z import (
    load_spectrum,
    process_spectrum,
    rebin_to_log,
    make_noise,
    calculate_velscale_fwhm,
    run_ppxf,
    plot_ppxf,
)

# %%
# --- Inputs ---
galaxy_files = [
    (f"../calibrated data/WB{i}_data.npy", f"../calibrated data/WB{i}_waveobs.npy")
    for i in range(1, 8)
]

# Match each dataset to its redshift (same order)
redshifts = [
    0.02852938,
    0.018225903,
    0.04171818,
    0.053875618,
    0.043503232,
    0.036721893,
    0.039853398]

# %%
window_size = 10
step        = 1
scale       = 0.4   # arcsec per pixel
pix_min, pix_max = 150, 250

all_results = {}

# --- Loop over galaxies ---
for (data_file, wave_file), z in zip(galaxy_files, redshifts):

    print(f"\nRunning galaxy {data_file} with z={z}")

    raw = np.load(data_file)       # flux × spatial pixel
    waveem = np.load(wave_file)

    results = []
    raw_roi = raw[:, pix_min:pix_max]

    for start in range(0, raw_roi.shape[1] - window_size + 1, step):
        end = start + window_size
        spectrum = raw_roi[:, start:end].sum(axis=1)

        # Build DataFrame
        df_spec = pd.DataFrame({
            "waveem": waveem,
            "flux":   spectrum
        })

        # Process, rebin, noise
        df_cut = process_spectrum(df_spec)
        df_rb, lam, flux_rb, ln_w = rebin_to_log(df_cut)

        noise = make_noise(df_rb)
        velscale, fwhm = calculate_velscale_fwhm(ln_w, lam)
        center = start + window_size//2 + pix_min

        # Run pPXF with galaxy's redshift
        pp = run_ppxf(lam, fwhm, velscale, df_rb, noise, redshift=z)

        print(f'  PIXEL: {center}')

        # Store result
        results.append((center, df_rb, pp))

    # Save per galaxy
    all_results[data_file] = results
# Out:
# Running galaxy ../calibrated data/WB1_data.npy with z=0.02852938
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8409        75
#  comp.  1:      8406       108
# chi2/DOF: 0.9653; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 126; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.544       3.7    8406   108
# Comp:  1             [SII]6716     0.1550       3.7    8406   108
# Comp:  1             [SII]6731      1.193       3.7    8406   108
# Comp:  1           [NII]6583_d      0.000       4.6    8406   108
# -----------------------------------------------------------------
#   PIXEL: 155
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8437         1
#  comp.  1:      8422       183
# chi2/DOF: 0.9676; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.608       4.0    8422   183
# Comp:  1             [SII]6716      0.000       4.1    8422   183
# Comp:  1             [SII]6731      0.000       4.1    8422   183
# Comp:  1           [NII]6583_d      0.000       5.1    8422   183
# -----------------------------------------------------------------
#   PIXEL: 156
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     10433      1000
#  comp.  1:      8447         1
# chi2/DOF: 0.9580; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 232; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       2.9    8447     1
# Comp:  1             [SII]6716     0.6629       2.9    8447     1
# Comp:  1             [SII]6731      2.206       2.9    8447     1
# Comp:  1           [NII]6583_d      0.000       3.7    8447     1
# -----------------------------------------------------------------
#   PIXEL: 157
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8491         1
#  comp.  1:      8401       181
# chi2/DOF: 0.9639; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 97; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.775       3.5    8401   181
# Comp:  1             [SII]6716      0.000       3.5    8401   181
# Comp:  1             [SII]6731    0.07178       3.5    8401   181
# Comp:  1           [NII]6583_d      0.000       4.4    8401   181
# -----------------------------------------------------------------
#   PIXEL: 158
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8510        42
#  comp.  1:      8386       202
# chi2/DOF: 0.9603; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.930       3.4    8386   202
# Comp:  1             [SII]6716      0.000       3.4    8386   202
# Comp:  1             [SII]6731      0.000       3.4    8386   202
# Comp:  1           [NII]6583_d      0.000       4.3    8386   202
# -----------------------------------------------------------------
#   PIXEL: 159
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8557        56
#  comp.  1:      8386       223
# chi2/DOF: 0.9535; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 98; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 2/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.468       3.0    8386   223
# Comp:  1             [SII]6716      0.000       3.1    8386   223
# Comp:  1             [SII]6731      0.000       3.1    8386   223
# Comp:  1           [NII]6583_d      0.000       3.8    8386   223
# -----------------------------------------------------------------
#   PIXEL: 160
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8581        42
#  comp.  1:      8382       220
# chi2/DOF: 0.9521; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 112; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.127       2.6    8382   220
# Comp:  1             [SII]6716     0.6521       2.6    8382   220
# Comp:  1             [SII]6731      1.046       2.6    8382   220
# Comp:  1           [NII]6583_d      0.000       3.2    8382   220
# -----------------------------------------------------------------
#   PIXEL: 161
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8582        94
#  comp.  1:      8387       232
# chi2/DOF: 0.9500; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.884       2.3    8387   232
# Comp:  1             [SII]6716     0.6753       2.4    8387   232
# Comp:  1             [SII]6731      1.376       2.4    8387   232
# Comp:  1           [NII]6583_d      0.000       3.0    8387   232
# -----------------------------------------------------------------
#   PIXEL: 162
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8621         1
#  comp.  1:      8348       228
# chi2/DOF: 0.9458; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 158; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.285       2.1    8348   228
# Comp:  1             [SII]6716      1.174       2.2    8348   228
# Comp:  1             [SII]6731      1.291       2.2    8348   228
# Comp:  1           [NII]6583_d      0.000       2.7    8348   228
# -----------------------------------------------------------------
#   PIXEL: 163
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8654         1
#  comp.  1:      8422       249
# chi2/DOF: 0.9268; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.369       1.8    8422   249
# Comp:  1             [SII]6716      1.487       1.8    8422   249
# Comp:  1             [SII]6731     0.4111       1.8    8422   249
# Comp:  1           [NII]6583_d      0.000       2.3    8422   249
# -----------------------------------------------------------------
#   PIXEL: 164
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8657         1
#  comp.  1:      8404       217
# chi2/DOF: 0.9124; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 139; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.307       1.5    8404   217
# Comp:  1             [SII]6716      1.209       1.5    8404   217
# Comp:  1             [SII]6731     0.5685       1.5    8404   217
# Comp:  1           [NII]6583_d     0.2781       1.9    8404   217
# -----------------------------------------------------------------
#   PIXEL: 165
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8675        34
#  comp.  1:      8417         1
# chi2/DOF: 0.8881; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 217; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.4900      0.92    8417     1
# Comp:  1             [SII]6716      1.020      0.92    8417     1
# Comp:  1             [SII]6731     0.3724      0.92    8417     1
# Comp:  1           [NII]6583_d      0.000       1.2    8417     1
# -----------------------------------------------------------------
#   PIXEL: 166
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8597       223
#  comp.  1:      8448         1
# chi2/DOF: 0.8547; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 185; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.5149      0.82    8448     1
# Comp:  1             [SII]6716      1.128      0.82    8448     1
# Comp:  1             [SII]6731    0.09815      0.82    8448     1
# Comp:  1           [NII]6583_d    0.02456       1.0    8448     1
# -----------------------------------------------------------------
#   PIXEL: 167
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8206       682
#  comp.  1:      8451         1
# chi2/DOF: 0.8247; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 215; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.6947      0.75    8451     1
# Comp:  1             [SII]6716      1.036      0.75    8451     1
# Comp:  1             [SII]6731     0.2507      0.75    8451     1
# Comp:  1           [NII]6583_d     0.2110      0.94    8451     1
# -----------------------------------------------------------------
#   PIXEL: 168
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      9026      1000
#  comp.  1:      8469        53
# chi2/DOF: 0.8946; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 19; Func calls: 290; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.4555      0.90    8469    53
# Comp:  1             [SII]6716     0.9105      0.90    8469    53
# Comp:  1             [SII]6731     0.3639      0.90    8469    53
# Comp:  1           [NII]6583_d    0.05487       1.1    8469    53
# -----------------------------------------------------------------
#   PIXEL: 169
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8219       654
#  comp.  1:      8422        92
# chi2/DOF: 0.8957; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha     0.8165      0.92    8422    92
# Comp:  1             [SII]6716     0.6676      0.92    8422    92
# Comp:  1             [SII]6731     0.5863      0.92    8422    92
# Comp:  1           [NII]6583_d     0.6482       1.2    8422    92
# -----------------------------------------------------------------
#   PIXEL: 170
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8142       693
#  comp.  1:      8438        70
# chi2/DOF: 0.8897; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 114; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.020      0.85    8438    70
# Comp:  1             [SII]6716     0.8005      0.85    8438    70
# Comp:  1             [SII]6731     0.4058      0.85    8438    70
# Comp:  1           [NII]6583_d      1.018       1.1    8438    70
# -----------------------------------------------------------------
#   PIXEL: 171
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8123       698
#  comp.  1:      8420        92
# chi2/DOF: 0.8889; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.530      0.86    8420    92
# Comp:  1             [SII]6716     0.5645      0.86    8420    92
# Comp:  1             [SII]6731     0.3300      0.86    8420    92
# Comp:  1           [NII]6583_d      1.274       1.1    8420    92
# -----------------------------------------------------------------
#   PIXEL: 172
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      7986       459
#  comp.  1:      8431        99
# chi2/DOF: 0.8865; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 97; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.584      0.85    8431    99
# Comp:  1             [SII]6716     0.6008      0.85    8431    99
# Comp:  1             [SII]6731     0.4784      0.85    8431    99
# Comp:  1           [NII]6583_d      1.383       1.1    8431    99
# -----------------------------------------------------------------
#   PIXEL: 173
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      7810       436
#  comp.  1:      8454       125
# chi2/DOF: 0.8928; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 110; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.083      0.91    8454   125
# Comp:  1             [SII]6716     0.6904      0.91    8454   125
# Comp:  1             [SII]6731     0.3858      0.91    8454   125
# Comp:  1           [NII]6583_d      1.521       1.2    8454   125
# -----------------------------------------------------------------
#   PIXEL: 174
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      6785      1000
#  comp.  1:      8486       109
# chi2/DOF: 0.9074; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 15; Func calls: 227; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      1.951      0.89    8486   109
# Comp:  1             [SII]6716     0.9186      0.89    8486   109
# Comp:  1             [SII]6731     0.3994      0.89    8486   109
# Comp:  1           [NII]6583_d     0.9346       1.1    8486   109
# -----------------------------------------------------------------
#   PIXEL: 175
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      7571      1000
#  comp.  1:      8456       128
# chi2/DOF: 0.9133; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.624      0.94    8456   128
# Comp:  1             [SII]6716     0.5709      0.94    8456   128
# Comp:  1             [SII]6731     0.2811      0.94    8456   128
# Comp:  1           [NII]6583_d      1.555       1.2    8456   128
# -----------------------------------------------------------------
#   PIXEL: 176
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8174      1000
#  comp.  1:      8433       177
# chi2/DOF: 0.9591; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.037       1.5    8433   177
# Comp:  1             [SII]6716     0.6735       1.5    8433   177
# Comp:  1             [SII]6731     0.4435       1.5    8433   177
# Comp:  1           [NII]6583_d      2.725       1.8    8433   177
# -----------------------------------------------------------------
#   PIXEL: 177
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      6433      1000
#  comp.  1:      8421       146
# chi2/DOF: 0.9515; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 13; Func calls: 202; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      3.225       1.4    8421   146
# Comp:  1             [SII]6716     0.6744       1.4    8421   146
# Comp:  1             [SII]6731     0.2565       1.4    8421   146
# Comp:  1           [NII]6583_d      1.947       1.8    8421   146
# -----------------------------------------------------------------
#   PIXEL: 178
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8477         1
#  comp.  1:      8420       161
# chi2/DOF: 0.9528; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.409       1.4    8420   161
# Comp:  1             [SII]6716      1.024       1.4    8420   161
# Comp:  1             [SII]6731     0.4696       1.4    8420   161
# Comp:  1           [NII]6583_d      2.557       1.8    8420   161
# -----------------------------------------------------------------
#   PIXEL: 179
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8455         1
#  comp.  1:      8399       174
# chi2/DOF: 0.9555; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.319       1.7    8399   174
# Comp:  1             [SII]6716      1.142       1.7    8399   174
# Comp:  1             [SII]6731     0.5231       1.7    8399   174
# Comp:  1           [NII]6583_d      2.591       2.1    8399   174
# -----------------------------------------------------------------
#   PIXEL: 180
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8444         1
#  comp.  1:      8363       168
# chi2/DOF: 0.9504; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 154; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.000       1.6    8363   168
# Comp:  1             [SII]6716      1.102       1.6    8363   168
# Comp:  1             [SII]6731     0.6738       1.6    8363   168
# Comp:  1           [NII]6583_d      2.962       2.1    8363   168
# -----------------------------------------------------------------
#   PIXEL: 181
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8453         1
#  comp.  1:      8346       161
# chi2/DOF: 0.9472; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 124; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      6.706       1.6    8346   161
# Comp:  1             [SII]6716      1.105       1.6    8346   161
# Comp:  1             [SII]6731     0.6693       1.6    8346   161
# Comp:  1           [NII]6583_d      3.290       2.0    8346   161
# -----------------------------------------------------------------
#   PIXEL: 182
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8450         1
#  comp.  1:      8322       142
# chi2/DOF: 0.9389; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.984       1.4    8322   142
# Comp:  1             [SII]6716     0.9849       1.4    8322   142
# Comp:  1             [SII]6731     0.4774       1.4    8322   142
# Comp:  1           [NII]6583_d      3.047       1.8    8322   142
# -----------------------------------------------------------------
#   PIXEL: 183
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8439         1
#  comp.  1:      8311       126
# chi2/DOF: 0.9251; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 122; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.686       1.3    8311   126
# Comp:  1             [SII]6716     0.9842       1.3    8311   126
# Comp:  1             [SII]6731     0.4532       1.3    8311   126
# Comp:  1           [NII]6583_d      2.879       1.6    8311   126
# -----------------------------------------------------------------
#   PIXEL: 184
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8397        72
#  comp.  1:      8300       115
# chi2/DOF: 0.9057; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 155; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.630       1.2    8300   115
# Comp:  1             [SII]6716     0.9553       1.2    8300   115
# Comp:  1             [SII]6731     0.5049       1.2    8300   115
# Comp:  1           [NII]6583_d      2.696       1.5    8300   115
# -----------------------------------------------------------------
#   PIXEL: 185
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8434         1
#  comp.  1:      8292       103
# chi2/DOF: 0.8879; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 140; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.994       1.1    8292   103
# Comp:  1             [SII]6716     0.9155       1.1    8292   103
# Comp:  1             [SII]6731     0.5995       1.1    8292   103
# Comp:  1           [NII]6583_d      2.368       1.3    8292   103
# -----------------------------------------------------------------
#   PIXEL: 186
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8294        94
#  comp.  1:      8264        66
# chi2/DOF: 0.8101; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 8/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.599      0.79    8264    66
# Comp:  1             [SII]6716     0.8026      0.79    8264    66
# Comp:  1             [SII]6731     0.6249      0.79    8264    66
# Comp:  1           [NII]6583_d      1.996       1.0    8264    66
# -----------------------------------------------------------------
#   PIXEL: 187
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8298       104
#  comp.  1:      8261        62
# chi2/DOF: 0.7292; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 154; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.104      0.67    8261    62
# Comp:  1             [SII]6716     0.8361      0.67    8261    62
# Comp:  1             [SII]6731     0.5577      0.67    8261    62
# Comp:  1           [NII]6583_d      1.811      0.85    8261    62
# -----------------------------------------------------------------
#   PIXEL: 188
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8284       271
#  comp.  1:      8252        39
# chi2/DOF: 0.5913; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 125; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.988      0.54    8252    39
# Comp:  1             [SII]6716     0.8155      0.54    8252    39
# Comp:  1             [SII]6731     0.6455      0.54    8252    39
# Comp:  1           [NII]6583_d      1.614      0.69    8252    39
# -----------------------------------------------------------------
#   PIXEL: 189
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8027       572
#  comp.  1:      8259        47
# chi2/DOF: 0.3408; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.641      0.43    8259    47
# Comp:  1             [SII]6716     0.7295      0.43    8259    47
# Comp:  1             [SII]6731     0.6356      0.43    8259    47
# Comp:  1           [NII]6583_d      1.736      0.55    8259    47
# -----------------------------------------------------------------
#   PIXEL: 190
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8016       555
#  comp.  1:      8280       119
# chi2/DOF: 0.2897; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 108; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.840      0.47    8280   119
# Comp:  1             [SII]6716     0.6791      0.47    8280   119
# Comp:  1             [SII]6731     0.4801      0.47    8280   119
# Comp:  1           [NII]6583_d      1.948      0.60    8280   119
# -----------------------------------------------------------------
#   PIXEL: 191
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8065       553
#  comp.  1:      8326       182
# chi2/DOF: 0.2714; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.962      0.54    8326   182
# Comp:  1             [SII]6716     0.9899      0.54    8326   182
# Comp:  1             [SII]6731     0.9043      0.54    8326   182
# Comp:  1           [NII]6583_d      2.023      0.68    8326   182
# -----------------------------------------------------------------
#   PIXEL: 192
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8159       487
#  comp.  1:      8392       226
# chi2/DOF: 0.2589; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 127; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.077      0.61    8392   226
# Comp:  1             [SII]6716     0.9455      0.62    8392   226
# Comp:  1             [SII]6731     0.6661      0.62    8392   226
# Comp:  1           [NII]6583_d      2.537      0.77    8392   226
# -----------------------------------------------------------------
#   PIXEL: 193
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8246       403
#  comp.  1:      8453       220
# chi2/DOF: 0.2561; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 6; Func calls: 92; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 7/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      4.493      0.62    8453   220
# Comp:  1             [SII]6716      1.453      0.63    8453   220
# Comp:  1             [SII]6731     0.8571      0.63    8453   220
# Comp:  1           [NII]6583_d      2.373      0.78    8453   220
# -----------------------------------------------------------------
#   PIXEL: 194
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8296       362
#  comp.  1:      8493       206
# chi2/DOF: 0.2572; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 127; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      5.711      0.63    8493   206
# Comp:  1             [SII]6716      1.507      0.64    8493   206
# Comp:  1             [SII]6731     0.8264      0.64    8493   206
# Comp:  1           [NII]6583_d      2.753      0.80    8493   206
# -----------------------------------------------------------------
#   PIXEL: 195
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8345       298
#  comp.  1:      8505       189
# chi2/DOF: 0.2504; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.287      0.63    8505   189
# Comp:  1             [SII]6716      1.558      0.64    8505   189
# Comp:  1             [SII]6731     0.7264      0.64    8505   189
# Comp:  1           [NII]6583_d      3.449      0.80    8505   189
# -----------------------------------------------------------------
#   PIXEL: 196
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8391       279
#  comp.  1:      8516       174
# chi2/DOF: 0.2632; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 78; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      7.852      0.62    8516   174
# Comp:  1             [SII]6716      1.596      0.63    8516   174
# Comp:  1             [SII]6731     0.9690      0.63    8516   174
# Comp:  1           [NII]6583_d      3.618      0.79    8516   174
# -----------------------------------------------------------------
#   PIXEL: 197
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8316       330
#  comp.  1:      8515       169
# chi2/DOF: 0.2789; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 123; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      8.837      0.64    8515   169
# Comp:  1             [SII]6716      1.777      0.64    8515   169
# Comp:  1             [SII]6731      1.196      0.64    8515   169
# Comp:  1           [NII]6583_d      4.119      0.80    8515   169
# -----------------------------------------------------------------
#   PIXEL: 198
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8384       236
#  comp.  1:      8519       161
# chi2/DOF: 0.3056; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 4; Func calls: 67; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      9.700      0.65    8519   161
# Comp:  1             [SII]6716      2.004      0.65    8519   161
# Comp:  1             [SII]6731      1.321      0.65    8519   161
# Comp:  1           [NII]6583_d      4.356      0.82    8519   161
# -----------------------------------------------------------------
#   PIXEL: 199
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8551       202
#  comp.  1:      8518       165
# chi2/DOF: 0.3573; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 184; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.09      0.68    8518   165
# Comp:  1             [SII]6716      2.384      0.69    8518   165
# Comp:  1             [SII]6731      1.444      0.69    8518   165
# Comp:  1           [NII]6583_d      4.643      0.86    8518   165
# -----------------------------------------------------------------
#   PIXEL: 200
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8484       308
#  comp.  1:      8511       165
# chi2/DOF: 0.4507; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.72      0.77    8511   165
# Comp:  1             [SII]6716      2.406      0.77    8511   165
# Comp:  1             [SII]6731      1.661      0.77    8511   165
# Comp:  1           [NII]6583_d      4.764      0.97    8511   165
# -----------------------------------------------------------------
#   PIXEL: 201
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      7685       198
#  comp.  1:      8510       153
# chi2/DOF: 0.7174; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 186; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 6/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.93       1.0    8510   153
# Comp:  1             [SII]6716      2.603       1.0    8510   153
# Comp:  1             [SII]6731      1.723       1.0    8510   153
# Comp:  1           [NII]6583_d      4.538       1.3    8510   153
# -----------------------------------------------------------------
#   PIXEL: 202
# Emission lines included in gas templates:
# ['Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' 'HeII4687' 'HeI5876' '[OIII]5007_d' '[OI]6300_d'
#  '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:      8017       811
# ...
#  Best Fit:       Vel     sigma
#  comp.  0:     11986        93
#  comp.  1:     11949        54
# chi2/DOF: 0.6837; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 218; Status: 4
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      14.43       2.1   11949    54
# Comp:  1             [SII]6716      0.000       2.1   11949    54
# Comp:  1             [SII]6731      0.000       1.2   11949    54
# Comp:  1           [NII]6583_d      2.004       2.6   11949    54
# -----------------------------------------------------------------
#   PIXEL: 230
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11980        58
#  comp.  1:     12000         1
# chi2/DOF: 0.6927; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 113; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.93       2.1   12000     1
# Comp:  1             [SII]6716      0.000       2.1   12000     1
# Comp:  1             [SII]6731      0.000       1.1   12000     1
# Comp:  1           [NII]6583_d      0.000       2.6   12000     1
# -----------------------------------------------------------------
#   PIXEL: 231
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11998         1
#  comp.  1:     12008         1
# chi2/DOF: 0.7039; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.71       2.2   12008     1
# Comp:  1             [SII]6716      0.000       2.2   12008     1
# Comp:  1             [SII]6731      0.000       1.2   12008     1
# Comp:  1           [NII]6583_d      0.000       2.7   12008     1
# -----------------------------------------------------------------
#   PIXEL: 232
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11986         1
#  comp.  1:     12010         1
# chi2/DOF: 0.7365; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 156; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      10.56       2.3   12010     1
# Comp:  1             [SII]6716      0.000       2.3   12010     1
# Comp:  1             [SII]6731      0.000       1.2   12010     1
# Comp:  1           [NII]6583_d      0.000       2.9   12010     1
# -----------------------------------------------------------------
#   PIXEL: 233
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11979         1
#  comp.  1:     12012         1
# chi2/DOF: 0.7737; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 10; Func calls: 159; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.09       2.7   12012     1
# Comp:  1             [SII]6716      0.000       2.7   12012     1
# Comp:  1             [SII]6731      0.000       1.5   12012     1
# Comp:  1           [NII]6583_d      0.000       3.4   12012     1
# -----------------------------------------------------------------
#   PIXEL: 234
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11891        52
#  comp.  1:     12007         1
# chi2/DOF: 0.9533; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 137; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.20       5.2   12007     1
# Comp:  1             [SII]6716      0.000       5.2   12007     1
# Comp:  1             [SII]6731      0.000       2.8   12007     1
# Comp:  1           [NII]6583_d      0.000       6.6   12007     1
# -----------------------------------------------------------------
#   PIXEL: 235
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11809       224
#  comp.  1:     11942       113
# chi2/DOF: 0.9727; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 109; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      20.89       8.3   11942   113
# Comp:  1             [SII]6716      0.000       8.3   11942   113
# Comp:  1             [SII]6731      0.000       4.9   11942   113
# Comp:  1           [NII]6583_d      5.631       10.   11942   113
# -----------------------------------------------------------------
#   PIXEL: 236
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11467      1000
#  comp.  1:     11990         1
# chi2/DOF: 0.9760; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 142; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      11.82       7.8   11990     1
# Comp:  1             [SII]6716      0.000       7.8   11990     1
# Comp:  1             [SII]6731      0.000       4.3   11990     1
# Comp:  1           [NII]6583_d      0.000       9.8   11990     1
# -----------------------------------------------------------------
#   PIXEL: 237
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     10692      1000
#  comp.  1:     12579        87
# chi2/DOF: 0.9757; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 14; Func calls: 218; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 1/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      2.432       9.1   12579    87
# Comp:  1             [SII]6716      0.000       5.7   12579    87
# Comp:  1             [SII]6731    0.03987      0.79   12579    87
# Comp:  1           [NII]6583_d      24.62       11.   12579    87
# -----------------------------------------------------------------
#   PIXEL: 238
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11831       124
#  comp.  1:     12028      1000
# chi2/DOF: 0.9753; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 143; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      0.000       65.   12028  1000
# Comp:  1             [SII]6716      0.000       75.   12028  1000
# Comp:  1             [SII]6731      0.000       65.   12028  1000
# Comp:  1           [NII]6583_d      81.59       71.   12028  1000
# -----------------------------------------------------------------
#   PIXEL: 239
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11816       143
#  comp.  1:     12013       194
# chi2/DOF: 0.9739; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 145; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      21.97       13.   12013   194
# Comp:  1             [SII]6716      0.000       14.   12013   194
# Comp:  1             [SII]6731      0.000       8.3   12013   194
# Comp:  1           [NII]6583_d      11.09       17.   12013   194
# -----------------------------------------------------------------
#   PIXEL: 240
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11804       146
#  comp.  1:     11894         1
# chi2/DOF: 0.9741; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 8; Func calls: 128; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      13.92       9.8   11894     1
# Comp:  1             [SII]6716      0.000       9.8   11894     1
# Comp:  1             [SII]6731      0.000       5.9   11894     1
# Comp:  1           [NII]6583_d      5.008       12.   11894     1
# -----------------------------------------------------------------
#   PIXEL: 241
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11818       152
#  comp.  1:     11883         1
# chi2/DOF: 0.9760; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 12; Func calls: 185; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      12.97       9.5   11883     1
# Comp:  1             [SII]6716      0.000       9.5   11883     1
# Comp:  1             [SII]6731      0.000       5.8   11883     1
# Comp:  1           [NII]6583_d      3.385       12.   11883     1
# -----------------------------------------------------------------
#   PIXEL: 242
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11824       150
#  comp.  1:     11906        86
# chi2/DOF: 0.9789; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 5; Func calls: 77; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 5/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      23.09       12.   11906    86
# Comp:  1             [SII]6716      0.000       12.   11906    86
# Comp:  1             [SII]6731      0.000       7.3   11906    86
# Comp:  1           [NII]6583_d      6.686       15.   11906    86
# -----------------------------------------------------------------
#   PIXEL: 243
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11811       118
#  comp.  1:     11911         6
# chi2/DOF: 0.9788; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 7; Func calls: 107; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 4/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      19.44       11.   11911     6
# Comp:  1             [SII]6716      0.000       11.   11911     6
# Comp:  1             [SII]6731      0.000       6.5   11911     6
# Comp:  1           [NII]6583_d      4.801       14.   11911     6
# -----------------------------------------------------------------
#   PIXEL: 244
# Emission lines included in gas templates:
# ['H8' 'Heps' 'Hdelta' 'Hgamma' 'Hbeta' 'Halpha' '[SII]6716' '[SII]6731'
#  '[NeIII]3968' '[NeIII]3869' 'HeII4687' 'HeI5876' '[OIII]5007_d'
#  '[OI]6300_d' '[NII]6583_d']
#  Best Fit:       Vel     sigma
#  comp.  0:     11837       166
#  comp.  1:     11909         1
# chi2/DOF: 0.9661; DOF: 1588; degree = 4; mdegree = 10
# method = capfit; Jac calls: 9; Func calls: 141; Status: 2
# linear_method = lsq_box; Nonzero Templates (>0.1%): 3/154
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# gas_component           name        flux       err      V     sig
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Comp:  1                Halpha      16.23       10.   11909     1
# Comp:  1             [SII]6716      0.000       10.   11909     1
# Comp:  1             [SII]6731      0.000       5.9   11909     1
# Comp:  1           [NII]6583_d      3.947       13.   11909     1
# -----------------------------------------------------------------
#   PIXEL: 245

# %%
import os
save_dir = "../halpha results Z"
os.makedirs(save_dir, exist_ok=True)

for data_file, results in all_results.items():
    galaxy_name = os.path.basename(data_file).replace("_data.npy", "")

    centers, velocities, v_errs, dispersions, sigma_errs, EWs, EW_errs = [], [], [], [], [], [], []

    for center, df_rb, pp in results:
        # --- extract Hα kinematics ---
        sol_gas = pp.sol[1]
        err_gas = pp.error[1]
        v_ha, sigma_ha = sol_gas
        v_ha_err, sigma_ha_err = err_gas

        # Hα index in gas templates
        idx = np.where(pp.gas_names == "Halpha")[0][0]

        flux_ha   = pp.gas_flux[idx]
        continuum = pp.bestfit - pp.gas_bestfit
        peak_i    = np.argmax(pp.gas_bestfit_templates[:, idx])
        cont0     = continuum[peak_i]
        cont_err  = pp.noise[peak_i]
        flux_err  = pp.gas_flux_error[idx]

        EW     = flux_ha / cont0
        EW_err = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)

        # store
        centers.append(center)
        velocities.append(v_ha)
        v_errs.append(v_ha_err)
        dispersions.append(sigma_ha)
        sigma_errs.append(sigma_ha_err)
        EWs.append(EW)
        EW_errs.append(EW_err)

    # Build DataFrame
    df = pd.DataFrame({
        "center":        centers,
        "velocity":      velocities,
        "velocity_err":  v_errs,
        "dispersion":    dispersions,
        "dispersion_err": sigma_errs,
        "EW":            EWs,
        "EW_err":        EW_errs
    })

    # Save one CSV per galaxy
    out_path = os.path.join(save_dir, f"{galaxy_name}_halpha_results.csv")
    df.to_csv(out_path, index=False)
    print(f"Saved {out_path}")
# Out:
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_6332/2878549075.py:28: RuntimeWarning: divide by zero encountered in scalar divide
#   EW_err = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# /var/folders/r3/l94405xd0mq2s62v2swzjq2m0000gn/T/ipykernel_6332/2878549075.py:28: RuntimeWarning: invalid value encountered in scalar multiply
#   EW_err = abs(EW) * np.sqrt((cont_err/cont0)**2 + (flux_err/flux_ha)**2)
# Saved ../halpha_results_Z/WB1_halpha_results.csv
# Saved ../halpha_results_Z/WB2_halpha_results.csv
# Saved ../halpha_results_Z/WB3_halpha_results.csv
# Saved ../halpha_results_Z/WB4_halpha_results.csv
# Saved ../halpha_results_Z/WB5_halpha_results.csv
# Saved ../halpha_results_Z/WB6_halpha_results.csv
# Saved ../halpha_results_Z/WB7_halpha_results.csv
